# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../pics/cover.png" width=600>
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# <img src="../pics/cover2.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX19wZ_2qR6K-hzIZau6cGqB

# %% [markdown]
# https://www.youtube.com/playlist?list=PLZeRcx60JO53wivRUDj-DfzwCzdugCfTY

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, x, y, z = sp.symbols("a, m, x, y, z", real=True)

# %% [markdown]
# ## Video 12
# Convertir 55.3 gramos a kg

# %%
from IPython.display import display, Math

# 1. Datos
peso_gr = 55.3 * u.g
peso_kg = peso_gr.to(u.kg)

print(f"{peso_gr} = {peso_kg:.4f}")
# Out:
# 55.3 g = 0.0553 kg
