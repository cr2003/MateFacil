# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
# C:\Users\crodr\Tutoriales\Math\MateFacil\pics\cover_curso_aritmetica.png
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# # Nivel 2 - Algebra elemental
# ## Curso de Algebra Elemental
#
# <img src="../../pics/cover_curso_algebra.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX1sF5fX83CleyK_SATfbhia

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\Tutoriales\\Math\\MateFacil\\Nivel_2_Algebra_elemental\\Curso_Algebra_Elemental'

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, b, c, d, m, n, p, q, r, s, t, v, x, y, z = sp.symbols(
    "a, b, c, d, m, n, p, q, r, s, t, v, x, y, z", real=True
)

spacing_equal = r"\,= \,"
spacing_approx = r"\, \approx \,"

# %% [markdown]
# #### Helper functions

# %%
def fmt(val, decimals=2):
    """Devuelve un entero si no tiene decimales, si tiene decimales los redondea a la cantidad pedida en decimals"""
    n = float(val)
    n = round(n, decimals)
    if n == int(n):
        return f"{int(n):,}"
    else:
        return f"{n:,.{decimals}f}"

# %% [markdown]
# ## Video 1
#
# ###  Suma y resta de números positivos y negativos
#
# * Dos números del mismo signo se suman, y se mantiene el signo en el resultado
#
# $$ -4 -3  $$

# %%
expr_raw = r" -4 -3   "
result = -sp.Integer(4) - sp.Integer(3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -4 -3    \,= \, -7$

# %% [markdown]
# $$ -2 -8  $$

# %%
expr_raw = r" -2 -8    "
result = -sp.Integer(2) - sp.Integer(8)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -2 -8     \,= \, -10$

# %% [markdown]
# $$ 3 +4  $$

# %%
expr_raw = r" 3 +4     "
result = sp.Integer(3) + sp.Integer(4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  3 +4      \,= \, 7$

# %% [markdown]
# * Dos números de diferente signo se restan, y se mantiene el signo del mayor
# $$ -4 +1  $$

# %%
expr_raw = r"  -4 +1     "
result = -sp.Integer(4) + sp.Integer(1)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   -4 +1      \,= \, -3$

# %% [markdown]
# $$ -2 +9  $$

# %%
expr_raw = r" -2 +9    "
result = -sp.Integer(2) + sp.Integer(9)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -2 +9     \,= \, 7$

# %% [markdown]
# ## Video 2
#
# ###  Suma y resta de números positivos y negativos (Respuestas)
#
#
# $$ -2 +10  $$

# %%
expr_raw = r" -2 +10   "
result = -sp.Integer(2) + sp.Integer(10)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -2 +10    \,= \, 8$

# %% [markdown]
# $$ -5 -5  $$

# %%
expr_raw = r" -5 -5   "
result = -sp.Integer(5) - sp.Integer(5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -5 -5    \,= \, -10$

# %% [markdown]
# $$ -3 +4  $$

# %%
expr_raw = r" -3 +4   "
result = -sp.Integer(3) + sp.Integer(4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -3 +4    \,= \, 1$

# %% [markdown]
# $$ 9 +1  $$

# %%
expr_raw = r"  9 +1   "
result = sp.Integer(9) + sp.Integer(1)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   9 +1    \,= \, 10$

# %% [markdown]
# $$ -3 +3  $$

# %%
expr_raw = r" -3 +3  "
result = -sp.Integer(3) + sp.Integer(3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -3 +3   \,= \, 0$

# %% [markdown]
# $$  -3 -3  $$

# %%
expr_raw = r" -3 -3   "
result = -sp.Integer(3) - sp.Integer(3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -3 -3    \,= \, -6$

# %% [markdown]
# $$ -8 +1  $$

# %%
expr_raw = r"-8 +1 "
result = -sp.Integer(8) + sp.Integer(1)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle -8 +1  \,= \, -7$

# %% [markdown]
# $$ 1 -8  $$

# %%
expr_raw = r" 1 -8  "
result = sp.Integer(1) - sp.Integer(8)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  1 -8   \,= \, -7$

# %% [markdown]
# $$ -1 +8 $$

# %%
expr_raw = r" -1 +8"
result = -sp.Integer(1) + sp.Integer(8)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -1 +8 \,= \, 7$

# %% [markdown]
# $$ -6 -10  $$

# %%
expr_raw = r" -6 -10 "
result = -sp.Integer(6) - sp.Integer(10)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -6 -10  \,= \, -16$

# %% [markdown]
# ## Video 3
#
# ###  Suma y resta de muchos números positivos y negativos
#
# $$ -2 +1 +5 -3 -2 +5 +1 -5 +3  $$

# %%
expr_raw = r" -2 +1 +5 -3 -2 +5 +1 -5 +3 "
result = -2 + 1 + 5 - 3 - 2 + 5 + 1 - 5 + 3
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -2 +1 +5 -3 -2 +5 +1 -5 +3  \,= \, 3$

# %% [markdown]
# ###  Suma y resta de muchos números positivos y negativos
#
# $$ 1 +9 -2 -8 +3 -7 +4 +6 -5  $$

# %%
expr_raw = r"  1 +9 -2 -8 +3 -7 +4 +6 -5  "
result = 1 + 9 - 2 - 8 + 3 - 7 + 4 + 6 - 5
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   1 +9 -2 -8 +3 -7 +4 +6 -5   \,= \, 1$

# %% [markdown]
# ## Video 4
# ###  Suma y resta de muchos números positivos y negativos (Respuestas)
# #### 1.
#
# $$ 2 -5 +3 +1 -2 +4  $$

# %%
expr_raw = r"  2 -5 +3 +1 -2 +4   "
result = 2 - 5 + 3 + 1 - 2 + 4
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   2 -5 +3 +1 -2 +4    \,= \, 3$

# %% [markdown]
# #### 2.
#
# $$ 1 -4 +3 +3 -8 -2  $$

# %%
expr_raw = r" 1 -4 +3 +3 -8 -2 "
result = 1 - 4 + 3 + 3 - 8 - 2
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  1 -4 +3 +3 -8 -2  \,= \, -7$

# %% [markdown]
# #### 3.
#
# $$ 2 +4 -1 -6 +2 -4 -2 +1 +8 $$

# %%
expr_raw = r" 2 +4 -1 -6 +2 -4 -2 +1 +8 "
result = 2 + 4 - 1 - 6 + 2 - 4 - 2 + 1 + 8
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2 +4 -1 -6 +2 -4 -2 +1 +8  \,= \, 4$

# %% [markdown]
# ## Video 7
# ###   Operaciones combinadas, Jerarquía de operaciones
#
# 1. Multiplicaciones
#
# 2. Sumas y restas
#
# $$ 1 +2 \times 3 + 4 $$

# %%
expr_raw = r"   1 +2 \times 3 + 4 "
result = 1 + 2 * 3 + 4
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle    1 +2 \times 3 + 4  \,= \, 11$

# %% [markdown]
# $$ 7 \times 2 - 3 \times 5 $$

# %%
expr_raw = r" 7 \times 2 - 3 \times 5  "
result = 7 * 2 - 3 * 5
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  7 \times 2 - 3 \times 5   \,= \, -1$

# %% [markdown]
# $$ 3(-1) -2(-5)$$

# %%
expr_raw = r" 3(-1) -2(-5)  "
result = 3 * (-1) - 2 * (-5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  3(-1) -2(-5)   \,= \, 7$

# %% [markdown]
# ## Video 8
# ###   Operaciones combinadas de sumas, restas y multiplicaciones
#
# $$ -1 +0 \times 3 -2 \times 5 $$

# %%
expr_raw = r" -1 +0 \times 3 -2 \times 5  "
result = -1 + 0 * 3 - 2 * 5
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -1 +0 \times 3 -2 \times 5   \,= \, -11$

# %% [markdown]
# $$ 2 +2 \times 2 +2 \times 2 $$

# %%
expr_raw = r" 2 +2 \times 2 +2 \times 2  "
result = 2 + 2 * 2 + 2 * 2
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2 +2 \times 2 +2 \times 2   \,= \, 10$

# %% [markdown]
# $$ (-2)(3)-2(-3) $$

# %%
expr_raw = r" (-2)(3)-2(-3) "
result = (-2) * (3) - 2 * (-3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (-2)(3)-2(-3)  \,= \, 0$

# %% [markdown]
# ## Video 9
# ###   Operaciones con paréntesis: suma, resta, multiplicación
#
# $$ -2(-1-1)+3(1-5) $$

# %%
expr_raw = r" -2(-1-1)+3(1-5) "
result = -2 * (-1 - 1) + 3 * (1 - 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -2(-1-1)+3(1-5)  \,= \, -8$

# %% [markdown]
# $$ (2-4)(1-3)+1 $$

# %%
expr_raw = r"  (2-4)(1-3)+1  "
result = (2 - 4) * (1 - 3) + 1
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   (2-4)(1-3)+1   \,= \, 5$

# %% [markdown]
# $$ 5+3(1-5)+2 $$

# %%
expr_raw = r"5+3(1-5)+2"
result = 5 + 3 * (1 - 5) + 2
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle 5+3(1-5)+2 \,= \, -5$

# %% [markdown]
# ## Video 10
#
# ###   Operaciones con paréntesis: suma, resta, multiplicación
#
# $$ 5 +2(-3-1) -2(3-4) $$

# %%
expr_raw = r"  5 +2(-3-1) -2(3-4) "
result = 5 + 2 * (-3 - 1) - 2 * (3 - 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   5 +2(-3-1) -2(3-4)  \,= \, -1$

# %% [markdown]
# $$ 2 -2(2-2) -2 -2(2-2) $$

# %%
expr_raw = r"  2 -2(2-2) -2 -2(2-2)  "
result = 2 - 2 * (2 - 2) - 2 - 2 * (2 - 2)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   2 -2(2-2) -2 -2(2-2)   \,= \, 0$

# %% [markdown]
# $$ (3+4) +2(3-1) -(-2-1) $$

# %%
expr_raw = r"  (3+4) +2(3-1) -(-2-1) "
result = (3 + 4) + 2 * (3 - 1) - (-2 - 1)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   (3+4) +2(3-1) -(-2-1)  \,= \, 14$

# %% [markdown]
# ## Video 11
#
# ###  Operaciones con paréntesis y corchetes
#
# $$ 1+2[-2(3+1) -2 -(2-5)]$$

# %%
expr_raw = r"1+2[-2(3+1) -2 -(2-5)]"
result = 1 + 2 * (-2 * (3 + 1) - 2 - (2 - 5))
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle 1+2[-2(3+1) -2 -(2-5)] \,= \, -13$

# %% [markdown]
# ## Video 12
#
# ###   Operaciones con paréntesis y corchetes
#
# $$ 2[2(2+2) -3(1-2-3) +1] +2(1-5) $$

# %%
expr_raw = r" 2[2(2+2) -3(1-2-3) +1] +2(1-5) "
result = 2 * (2 * (2 + 2) - 3 * (1 - 2 - 3) + 1) + 2 * (1 - 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2[2(2+2) -3(1-2-3) +1] +2(1-5)  \,= \, 34$

# %% [markdown]
# ## Video 13
#
# ###  Operaciones con paréntesis, corchetes y llaves
#
# $$ 1 +2\{2 -3[1 -2(3+1) +4(2-1)]\} $$

# %%
expr_raw = r" 1 +2\{2 -3[1 -2(3+1) +4(2-1)]\} "
result = 1 + 2 * (2 - 3 * (1 - 2 * (3 + 1) + 4 * (2 - 1)))
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  1 +2\{2 -3[1 -2(3+1) +4(2-1)]\}  \,= \, 23$

# %% [markdown]
# ## Video 14
#
# ###  Operaciones con paréntesis, corchetes y llaves
#
# $$ 2 -\{[2 +3(-2+1)][(2)(-3+1) -2] +1 \} $$

# %%
expr_raw = r"  2 -\{[2 +3(-2+1)][(2)(-3+1) -2] +1 \} "
result = 2 - ((2 + 3 * (-2 + 1)) * ((2) * (-3 + 1) - 2) + 1)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   2 -\{[2 +3(-2+1)][(2)(-3+1) -2] +1 \}  \,= \, -5$

# %% [markdown]
# ## Video 15
#
# ###  Resumen de fracciones: suma, resta, multiplicación y división de fracciones con signo
#
# $$ \frac{2}{5} + \frac{1}{5} $$

# %%
expr_raw = r" \frac{2}{5} + \frac{1}{5} "
result = sp.Rational(2, 5) + sp.Rational(1, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{2}{5} + \frac{1}{5}  \,= \, \frac{3}{5}$

# %% [markdown]
# $$ \frac{1}{2} + \frac{3}{5} $$

# %%
expr_raw = r" \frac{1}{2} + \frac{3}{5} "
result = sp.Rational(1, 2) + sp.Rational(3, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{1}{2} + \frac{3}{5}  \,= \, \frac{11}{10}$

# %% [markdown]
# $$ \frac{1}{3} - \frac{2}{5} $$

# %%
expr_raw = r" \frac{1}{3} - \frac{2}{5}  "
result = sp.Rational(1, 3) - sp.Rational(2, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{1}{3} - \frac{2}{5}   \,= \, - \frac{1}{15}$

# %% [markdown]
# $$ -\frac{1}{2} - \frac{2}{3} $$

# %%
expr_raw = r" -\frac{1}{2} - \frac{2}{3}  "
result = -sp.Rational(1, 2) - sp.Rational(2, 3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -\frac{1}{2} - \frac{2}{3}   \,= \, - \frac{7}{6}$

# %% [markdown]
# $$ -\frac{3}{4} + \frac{1}{3} $$

# %%
expr_raw = r" -\frac{3}{4} + \frac{1}{3} "
result = -sp.Rational(3, 4) + sp.Rational(1, 3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -\frac{3}{4} + \frac{1}{3}  \,= \, - \frac{5}{12}$

# %% [markdown]
# $$ \frac{2}{3} - 2 $$

# %%
expr_raw = r" \frac{2}{3} - 2 "
result = sp.Rational(2, 3) - 2
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{2}{3} - 2  \,= \, - \frac{4}{3}$

# %% [markdown]
# $$ \frac{1}{2} + \frac{2}{3} - \frac{3}{4} $$

# %%
expr_raw = r" \frac{1}{2} + \frac{2}{3} - \frac{3}{4} "
result = sp.Rational(1, 2) + sp.Rational(2, 3) - sp.Rational(3, 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{1}{2} + \frac{2}{3} - \frac{3}{4}  \,= \, \frac{5}{12}$

# %% [markdown]
# $$ \frac{2}{3} \left( \frac{4}{5} \right) $$

# %%
expr_raw = r" \frac{2}{3} \left( \frac{4}{5} \right)  "
result = sp.Rational(2, 3) * sp.Rational(4, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{2}{3} \left( \frac{4}{5} \right)   \,= \, \frac{8}{15}$

# %% [markdown]
# $$ -\frac{2}{3} \left( \frac{1}{4} \right) $$

# %%
expr_raw = r" -\frac{2}{3} \left( \frac{1}{4} \right)  "
result = -sp.Rational(2, 3) * sp.Rational(1, 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -\frac{2}{3} \left( \frac{1}{4} \right)   \,= \, - \frac{1}{6}$

# %% [markdown]
# $$-4 \left(- \frac{2}{3} \right) $$

# %%
expr_raw = r" -4 \left(- \frac{2}{3} \right) "
result = -4 * -sp.Rational(2, 3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -4 \left(- \frac{2}{3} \right)  \,= \, \frac{8}{3}$

# %% [markdown]
# $$ \frac{2}{3} \left( -\frac{1}{2} \right) \left( \frac{2}{5} \right)$$

# %%
expr_raw = r" \frac{2}{3} \left( -\frac{1}{2} \right) \left( \frac{2}{5} \right)  "
result = sp.Rational(2, 3) * -sp.Rational(1, 2) * sp.Rational(2, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{2}{3} \left( -\frac{1}{2} \right) \left( \frac{2}{5} \right)   \,= \, - \frac{2}{15}$

# %% [markdown]
# $$ \frac{2}{3} \div  \frac{1}{4} $$

# %%
expr_raw = r" \frac{2}{3} \div  \frac{1}{4}   "
result = sp.Rational(2, 3) / sp.Rational(1, 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{2}{3} \div  \frac{1}{4}    \,= \, \frac{8}{3}$

# %% [markdown]
# $$ -\frac{3}{5} \div  \frac{2}{7} $$

# %%
expr_raw = r" -\frac{3}{5} \div  \frac{2}{7}  "
result = -sp.Rational(3, 5) / sp.Rational(2, 7)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -\frac{3}{5} \div  \frac{2}{7}   \,= \, - \frac{21}{10}$

# %% [markdown]
# ## Video 16
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \frac{2}{3} + \frac{1}{2}\left( -\frac{3}{5} \right) $$

# %%
expr_raw = r" \frac{2}{3} + \frac{1}{2}\left( -\frac{3}{5} \right)  "
result = sp.Rational(2, 3) + sp.Rational(1, 2) * -sp.Rational(3, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{2}{3} + \frac{1}{2}\left( -\frac{3}{5} \right)   \,= \, \frac{11}{30}$

# %% [markdown]
# $$ \left( 2 +\frac{1}{2} \right) \left( \frac{1}{3} - 2 \right)  $$

# %%
expr_raw = r"  \left( 2 +\frac{1}{2} \right) \left( \frac{1}{3} - 2 \right)   "
result = (2 + sp.Rational(1, 2)) * (sp.Rational(1, 3) - 2)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   \left( 2 +\frac{1}{2} \right) \left( \frac{1}{3} - 2 \right)    \,= \, - \frac{25}{6}$

# %% [markdown]
# ## Video 17
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ 2 -\left( \frac{1}{2} \right) \left( \frac{2}{3} \right) - \frac{3}{4} $$

# %%
expr_raw = r" 2 -\left( \frac{1}{2} \right) \left( \frac{2}{3} \right) - \frac{3}{4} "
result = 2 - (sp.Rational(1, 2)) * (sp.Rational(2, 3)) - sp.Rational(3, 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2 -\left( \frac{1}{2} \right) \left( \frac{2}{3} \right) - \frac{3}{4}  \,= \, \frac{11}{12}$

# %% [markdown]
# $$ \frac{3}{5} \left( \frac{1}{2} - \frac{2}{3}\right) + \frac{1}{2} $$

# %%
expr_raw = r"  \frac{3}{5} \left( \frac{1}{2} - \frac{2}{3}\right) + \frac{1}{2} "
result = sp.Rational(3, 5) * ((sp.Rational(1, 2)) - sp.Rational(2, 3)) + sp.Rational(
    1, 2
)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   \frac{3}{5} \left( \frac{1}{2} - \frac{2}{3}\right) + \frac{1}{2}  \,= \, \frac{2}{5}$

# %% [markdown]
# ## Video 18
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \left(1 + \frac{3}{4} \right) \div \left( \frac{2}{3} + \frac{1}{5} \right) $$

# %%
expr_raw = (
    r" \left(1 + \frac{3}{4} \right) \div \left( \frac{2}{3} + \frac{1}{5} \right)  "
)
result = (1 + sp.Rational(3, 4)) / (sp.Rational(2, 3) + sp.Rational(1, 5))


display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left(1 + \frac{3}{4} \right) \div \left( \frac{2}{3} + \frac{1}{5} \right)   \,= \, \frac{105}{52}$

# %% [markdown]
# ## Video 19
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \left(1 -\frac{1}{2} + \frac{3}{4} \right) \div \left( \frac{2}{5} - \frac{1}{8} \right) $$

# %%
expr_raw = r" \left(1 -\frac{1}{2} + \frac{3}{4} \right) \div \left( \frac{2}{5} - \frac{1}{8} \right)   "
result = (1 - sp.Rational(1, 2) + sp.Rational(3, 4)) / (
    sp.Rational(2, 5) - sp.Rational(1, 8)
)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left(1 -\frac{1}{2} + \frac{3}{4} \right) \div \left( \frac{2}{5} - \frac{1}{8} \right)    \,= \, \frac{50}{11}$

# %% [markdown]
# ## Video 20
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \left( \frac{4}{5} - \frac{1}{2} \right) - \left( \frac{1}{3} + \frac{1}{6} \right) $$

# %%
expr_raw = r" \left( \frac{4}{5} - \frac{1}{2} \right) - \left( \frac{1}{3} + \frac{1}{6} \right) "
result = (sp.Rational(4, 5) - sp.Rational(1, 2)) - (
    sp.Rational(1, 3) + sp.Rational(1, 6)
)


display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left( \frac{4}{5} - \frac{1}{2} \right) - \left( \frac{1}{3} + \frac{1}{6} \right)  \,= \, - \frac{1}{5}$
