# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
# C:\Users\crodr\Tutoriales\Math\MateFacil\pics\cover_curso_aritmetica.png
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# # Nivel 2 - Algebra elemental
# ## Curso de Algebra Elemental
#
# <img src="../../pics/cover_curso_algebra.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX1sF5fX83CleyK_SATfbhia

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\Tutoriales\\Math\\MateFacil\\Nivel_2_Algebra_elemental\\Curso_Algebra_Elemental'

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, b, c, d, m, n, p, q, r, s, t, v, x, y, z = sp.symbols(
    "a, b, c, d, m, n, p, q, r, s, t, v, x, y, z", real=True
)

spacing_equal = r"\,= \,"
spacing_approx = r"\, \approx \,"

# %% [markdown]
# #### Helper functions

# %%
def fmt(val, decimals=2):
    """Devuelve un entero si no tiene decimales, si tiene decimales los redondea a la cantidad pedida en decimals"""
    n = float(val)
    n = round(n, decimals)
    if n == int(n):
        return f"{int(n):,}"
    else:
        return f"{n:,.{decimals}f}"

# %% [markdown]
# ## Video 21
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \left( \frac{3}{2} - \frac{1}{4} \right) + \left( \frac{2}{5} - \frac{1}{2} \right) $$

# %%
expr_raw = r" \left( \frac{3}{2} - \frac{1}{4} \right) + \left( \frac{2}{5} - \frac{1}{2} \right) "
result = (sp.Rational(3, 2) - sp.Rational(1, 4)) + (
    sp.Rational(2, 5) - sp.Rational(1, 2)
)


display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left( \frac{3}{2} - \frac{1}{4} \right) + \left( \frac{2}{5} - \frac{1}{2} \right)  \,= \, \frac{23}{20}$

# %% [markdown]
# ## Video 22
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \frac{2}{3} - \left( \frac{1}{5} - \frac{6}{5} \right) \cdot \frac{1}{3} $$

# %%
expr_raw = r" \frac{2}{3} - \left( \frac{1}{5} - \frac{6}{5} \right) \cdot \frac{1}{3} "
result = sp.Rational(2, 3) - (sp.Rational(1, 5) - sp.Rational(6, 5)) * sp.Rational(1, 3)


display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{2}{3} - \left( \frac{1}{5} - \frac{6}{5} \right) \cdot \frac{1}{3}  \,= \, 1$

# %% [markdown]
# ## Video 35
#
# ###  Repaso de potencias (Parte 1): exponentes positivos y negativos
#
# $$3^2 = (3)(3) = 9 $$

# %%
expr_raw = r" 3^2 "
result = 3**2

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  3^2  \,= \, 9$

# %% [markdown]
# $$(-5)^2 = (-5)(-5) = 25 $$

# %%
expr_raw = r" (-5)^2"
result = (-5) ** 2

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (-5)^2 \,= \, 25$

# %% [markdown]
# $$-5^2 = -(5)(5) = -25 $$

# %%
expr_raw = r" -5^2"
result = -(5**2)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -5^2 \,= \, -25$

# %% [markdown]
# $$4^1 = 4 $$

# %%
expr_raw = r" 4^1"
result = 4**1

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  4^1 \,= \, 4$

# %% [markdown]
# $$4^0 = 1 $$

# %%
expr_raw = r"4^0 "
result = 4**0

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle 4^0  \,= \, 1$

# %% [markdown]
# $$3^{-2} = \frac{1}{3^2} = \frac{1}{9} $$

# %%
expr_raw = r" 3^{-2}"
result = sp.Integer(3) ** -2

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  3^{-2} \,= \, \frac{1}{9}$

# %% [markdown]
# $$ 2^{-4} $$

# %%
expr_raw = r" 2^{-4}"
result = sp.Integer(2) ** -4

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2^{-4} \,= \, \frac{1}{16}$

# %% [markdown]
# $$ (-3)^{-2} $$

# %%
expr_raw = r" (-3)^{-2} "
result = sp.Integer(-3) ** -2

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (-3)^{-2}  \,= \, \frac{1}{9}$

# %% [markdown]
# $$ -3^{-2} $$

# %%
expr_raw = r" -3^{-2} "
result = -(sp.Integer(3) ** -2)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  -3^{-2}  \,= \, - \frac{1}{9}$

# %% [markdown]
# $$ 5^{-1} $$

# %%
expr_raw = r"  5^{-1} "
result = sp.Integer(5) ** -1

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   5^{-1}  \,= \, \frac{1}{5}$

# %% [markdown]
# ## Video 36
#
# ###  Repaso de potencias
#
# $$4^{-3}$$

# %%
expr_raw = r"  4^{-3} "
result = sp.Integer(4) ** -3

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle   4^{-3}  \,= \, \frac{1}{64}$

# %% [markdown]
# $$ 1^{10} $$

# %%
expr_raw = r" 1^{10}"
result = sp.Integer(1) ** 10

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  1^{10} \,= \, 1$

# %% [markdown]
# $$ 0^{100} $$

# %%
expr_raw = r" 0^{100} "
result = sp.Integer(0) ** 100

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  0^{100}  \,= \, 0$

# %% [markdown]
# $$ (-1)^{9} $$

# %%
expr_raw = r" (-1)^{9}  "
result = sp.Integer(-1) ** 9

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (-1)^{9}   \,= \, -1$

# %% [markdown]
# $$ (-1)^{10} $$

# %%
expr_raw = r" (-1)^{10}  "
result = sp.Integer(-1) ** 10

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (-1)^{10}   \,= \, 1$

# %% [markdown]
# $$ (-2894320)^{0} $$

# %%
expr_raw = r" (-2894320)^{0}  "
result = sp.Integer(-2894320) ** 0

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (-2894320)^{0}   \,= \, 1$

# %% [markdown]
# ## Video 37
#
# ### Ejercicios con exponentes: sumas de potencias positivas y negativas
#
# $$2^4 -3^2 $$

# %%
expr_raw = r" 2^4 -3^2  "
result = sp.Integer(2) ** 4 - sp.Integer(3) ** 2

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2^4 -3^2   \,= \, 7$

# %% [markdown]
# $$ 2^0 +2^1 +2^2 +2^3 $$

# %%
expr_raw = r" 2^0 +2^1 +2^2 +2^3 "
result = (
    sp.Integer(2) ** 0 + sp.Integer(2) ** 1 + sp.Integer(2) ** 2 + sp.Integer(2) ** 3
)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2^0 +2^1 +2^2 +2^3  \,= \, 15$

# %% [markdown]
# $$ 2^{-1} +5^{-1} $$

# %%
expr_raw = r" 2^{-1} +5^{-1} "
result = sp.Integer(2) ** -1 + sp.Integer(5) ** -1

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2^{-1} +5^{-1}  \,= \, \frac{7}{10}$

# %% [markdown]
# ## Video 38
#
# ### Ejercicios con exponentes: sumas de potencias positivas y negativas
#
# $$ 5^2 -4^2 +3^2 -2^2 +1^2 -0^2 $$

# %%
expr_raw = r" 5^2 -4^2 +3^2 -2^2 +1^2 -0^2 "
result = (
    sp.Integer(5) ** 2
    - sp.Integer(4) ** 2
    + sp.Integer(3) ** 2
    - sp.Integer(2) ** 2
    + sp.Integer(1) ** 2
    - sp.Integer(0) ** 2
)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  5^2 -4^2 +3^2 -2^2 +1^2 -0^2  \,= \, 15$

# %% [markdown]
# $$ 7^2 -(-1)^5 $$

# %%
expr_raw = r" 7^2 -(-1)^5  "
result = sp.Integer(7) ** 2 - sp.Integer(-1) ** 5

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  7^2 -(-1)^5   \,= \, 50$

# %% [markdown]
# $$ 2^3 -(-3)^3 $$

# %%
expr_raw = r" 2^3 -(-3)^3  "
result = sp.Integer(2) ** 3 - sp.Integer(-3) ** 3

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2^3 -(-3)^3   \,= \, 35$

# %% [markdown]
# ## Video 39
#
# ### Ejercicios con exponentes y paréntesis
#
# $$ (1+3^2)^3 $$

# %%
expr_raw = r" (1+3^2)^3  "
result = (sp.Integer(1) + sp.Integer(3) ** 2) ** 3

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (1+3^2)^3   \,= \, 1000$

# %% [markdown]
# $$ 2^0 -(2^1 - 2^2) $$

# %%
expr_raw = r" 2^0 -(2^1 - 2^2)  "
result = sp.Integer(2) ** 0 - (sp.Integer(2) ** 1 - sp.Integer(2) ** 2)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2^0 -(2^1 - 2^2)   \,= \, 3$

# %% [markdown]
# $$ 2 +3(1^2 - 6^2) $$

# %%
expr_raw = r" 2 +3(1^2 - 6^2)  "
result = sp.Integer(2) + sp.Integer(3) * (sp.Integer(1) ** 2 - sp.Integer(6) ** 2)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2 +3(1^2 - 6^2)   \,= \, -103$

# %% [markdown]
# ## Video 40
#
# ### Repaso de potencias (Parte 2): fracciones con exponente negativo, y positivo
#
# $$ \left( \frac{2}{3} \right)^3 $$

# %%
expr_raw = r" \left( \frac{2}{3} \right)^3  "
result = (sp.Integer(2) / sp.Integer(3)) ** 3

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left( \frac{2}{3} \right)^3   \,= \, \frac{8}{27}$

# %% [markdown]
# $$ \left( \frac{5}{7} \right)^0 $$

# %%
expr_raw = r" \left( \frac{5}{7} \right)^0  "
result = (sp.Integer(5) / sp.Integer(7)) ** 0

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left( \frac{5}{7} \right)^0   \,= \, 1$

# %% [markdown]
# $$ \left( \frac{5}{7} \right)^1 $$

# %%
expr_raw = r" \left( \frac{5}{7} \right)^1  "
result = (sp.Integer(5) / sp.Integer(7)) ** 1

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left( \frac{5}{7} \right)^1   \,= \, \frac{5}{7}$

# %% [markdown]
# $$ \left( \frac{4}{9} \right)^{-1} $$

# %%
expr_raw = r" \left( \frac{4}{9} \right)^{-1}  "
result = (sp.Integer(4) / sp.Integer(9)) ** -1

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left( \frac{4}{9} \right)^{-1}   \,= \, \frac{9}{4}$

# %% [markdown]
# $$ \left( \frac{1}{5} \right)^{-1} $$

# %%
expr_raw = r" \left( \frac{1}{5} \right)^{-1} "
result = (sp.Integer(1) / sp.Integer(5)) ** -1

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left( \frac{1}{5} \right)^{-1}  \,= \, 5$

# %% [markdown]
# $$ \left( \frac{5}{3} \right)^{-2} $$

# %%
expr_raw = r" \left( \frac{5}{3} \right)^{-2}   "
result = (sp.Integer(5) / sp.Integer(3)) ** -2

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \left( \frac{4}{9} \right)^{-1}   \,= \, \frac{9}{4}$
