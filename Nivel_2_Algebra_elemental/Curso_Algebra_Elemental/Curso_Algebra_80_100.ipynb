# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
# C:\Users\crodr\Tutoriales\Math\MateFacil\pics\cover_curso_aritmetica.png
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# # Nivel 2 - Algebra elemental
# ## Curso de Algebra Elemental
#
# <img src="../../pics/cover_curso_algebra.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX1sF5fX83CleyK_SATfbhia

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\Tutoriales\\Math\\MateFacil\\Nivel_2_Algebra_elemental\\Curso_Algebra_Elemental'

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, b, c, d, m, n, p, q, r, s, t, v, x, y, z = sp.symbols(
    "a, b, c, d, m, n, p, q, r, s, t, v, x, y, z", real=True
)

spacing_equal = r"\,= \,"
spacing_approx = r"\, \approx \,"

# %% [markdown]
# #### Helper functions

# %%
def fmt(val, decimals=2):
    """Devuelve un entero si no tiene decimales, si tiene decimales los redondea a la cantidad pedida en decimals"""
    n = float(val)
    n = round(n, decimals)
    if n == int(n):
        return f"{int(n):,}"
    else:
        return f"{n:,.{decimals}f}"

# %% [markdown]
# ## Video 81
# ### Jerarquía de Operaciones: Una explicación definitiva para estudiantes curiosos
#
# * P - Paréntesis
# * E - Exponentes
#     * M - Multiplicación
#     * D - División
#     * A - Adición
#     * S - Sustracción
#
# $$
# 5 + 2 \cdot 3
# $$

# %%
expr_raw = r" 5 + 2 \cdot 3 "
result = sp.Integer(5) + sp.Integer(2) * sp.Integer(3)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  5 + 2 \cdot 3  \,= \, 11$

# %% [markdown]
# $$
# (5 + 2) \cdot 3
# $$

# %%
expr_raw = r" (5 + 2) \cdot 3 "
result = (sp.Integer(5) + sp.Integer(2)) * sp.Integer(3)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (5 + 2) \cdot 3  \,= \, 21$

# %% [markdown]
# $$
# 12 \div 2 \times 3
# $$

# %%
expr_raw = r" 12 \div 2 \times 3 "
result = sp.Integer(12) / sp.Integer(2) * sp.Integer(3)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  12 \div 2 \times 3  \,= \, 18$

# %% [markdown]
# $$
# 2 +3 \times 2^2
# $$

# %%
expr_raw = r" 2 +3 \times 2^2 "
result = sp.Integer(2) + sp.Integer(3) * sp.Integer(2) ** 2

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2 +3 \times 2^2  \,= \, 14$

# %% [markdown]
# $$
# 8 \div 2 (2+2)
# $$

# %%
expr_raw = r" 8 \div 2 (2+2)"
result = sp.Integer(8) / sp.Integer(2) * (sp.Integer(2) + sp.Integer(2))

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  8 \div 2 (2+2) \,= \, 16$

# %% [markdown]
# ## Video 84
# ###   LENGUAJE ALGEBRAICO, Expresar usando variables
#
# La suma de tres números
#
# $$x + y + z$$

# %% [markdown]
# El producto de cuatro números
#
# $$w x y z $$

# %% [markdown]
# El triple de un número
#
# $$3x $$

# %% [markdown]
# La tercera parte de un número
#
# $$\frac{1}{3}x $$

# %% [markdown]
# La suma de un número y su cuadrado
#
# $$
# x + x^2
# $$

# %% [markdown]
# La suma de un número y el triple de otro
#
# $$
# x + 3y
# $$

# %% [markdown]
# El cubo de un número
#
# $$
# x^3
# $$

# %% [markdown]
# El producto de un número con el cubo de otro
#
# $$
# x  y^3
# $$

# %% [markdown]
# El doble del producto de dos números
#
# $$
# 2xy
# $$

# %% [markdown]
# ## Video 85
# ###   LENGUAJE ALGEBRAICO, Expresar usando variables
#
# El triple del producto de dos números
#
# $$
# 3xy
# $$

# %% [markdown]
# El doble de la suma de dos números
#
# $$
# 2(x + y)
# $$

# %% [markdown]
# La quinta parte de un número
#
# $$
# \frac{1}{5}x
# $$

# %% [markdown]
# El producto del cuadrado de un número con el cubo de otro
#
# $$
# x^2 y^3
# $$

# %% [markdown]
# El cociente del cuadrado de un número entre el cubo de otro
#
# $$
# \frac{x^2}{y^3}
# $$

# %% [markdown]
# La diferencia del triple de un número menos el cubo de otro
#
# $$
# 3x - y^3
# $$

# %% [markdown]
# El cuadrado de la suma de dos números
#
# $$
# (x + y)^2
# $$

# %% [markdown]
# El cubo de la diferencia de dos números
#
# $$
# (x - y)^3
# $$

# %% [markdown]
# ## Video 86
# ###    VALOR NUMÉRICO de una expresión algebraica
#
# $$
# 2x + 3y \;\; x=3, y=5
# $$

# %%
expr_raw = r" 2x + 3y "
expr = 2 * x + 3 * y

valores = {x: 3, y: 5}
result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2x + 3y  \,= \, 21$

# %% [markdown]
# $$
# 4x -  2xy \;\; x=-1, y=6
# $$

# %%
expr_raw = r" 4x - 2xy"
expr = 4 * x - 2 * x * y

valores = {x: -1, y: 6}
result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  4x - 2xy \,= \, 8$

# %% [markdown]
# $$
# 3abc \;\; a=-1, b=2, c=-3
# $$

# %%
expr_raw = r" 3abc"
expr = 3 * a * b * c

valores = {a: -1, b: 2, c: -3}
result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  3abc \,= \, 18$

# %% [markdown]
# ## Video 87
# ###    VALOR NUMÉRICO de una expresión algebraica
#
# Dados los valores de las variables:
#
# $a=2, b=-4, c=1, x=-3, y=3$
#
# calcular las siguientes expresiones:
#
# $$
# 2a -3b + c
# $$

# %%
valores = {a: 2, b: -4, c: 1, x: -3, y: 3}

# %%
expr_raw = r" 2a -3b + c"
expr = 2 * a - 3 * b + c

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  2a -3b + c \,= \, 17$

# %% [markdown]
# $$
# a^2 +b^2 + c^2
# $$

# %%
expr_raw = r" a^2 +b^2 + c^2 "
expr = a**2 + b**2 + c**2

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  a^2 +b^2 + c^2  \,= \, 21$

# %% [markdown]
# $$
# ax +by
# $$

# %%
expr_raw = r" ax +by"
expr = a * x + b * y

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  ax +by \,= \, -18$

# %% [markdown]
# $$
# (x - b)^2
# $$

# %%
expr_raw = r" (x - b)^2 "
expr = (x - b) ** 2

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (x - b)^2  \,= \, 1$

# %% [markdown]
# $$
# y^a +a^y
# $$

# %%
expr_raw = r" y^a +a^y "
expr = y**a + a**y

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  y^a +a^y  \,= \, 17$

# %% [markdown]
# ## Video 88
# ### VALOR NUMÉRICO de una expresión algebraica, Con FRACCIONES
#
# Dados los valores de las variables:
#
# $x=-1, y=-2, z=-3, a=-1$
#
# calcular las siguientes expresiones:
#
# $$
# a^2 x^3 y^4
# $$

# %%
valores = {x: 1, y: -2, z: -3, a: -1}

# %%
expr_raw = r" a^2 x^3 y^4"
expr = a**2 * x**3 * y**4

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  a^2 x^3 y^4 \,= \, 16$

# %% [markdown]
# $$
# \frac{3x-2y}{z^2}
# $$

# %%
expr_raw = r" \frac{3x-2y}{z^2} "
expr = (3 * x - 2 * y) / (z**2)

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{3x-2y}{z^2}  \,= \, \frac{7}{9}$

# %% [markdown]
# $$
# \frac{a}{x} + \frac{2a}{z}
# $$

# %%
expr_raw = r" \frac{a}{x} + \frac{2a}{z} "
expr = (a / x) + (2 * a / z)

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{a}{x} + \frac{2a}{z}  \,= \, - \frac{1}{3}$

# %% [markdown]
# ## Video 89
# ### VALOR NUMÉRICO de una expresión algebraica, Con FRACCIONES
#
# Dados los valores de las variables:
#
# $ m=\frac{1}{2}, n=\frac{2}{3}, p=-\frac{1}{3}$
#
# calcular las siguientes expresiones:
#
# $$
# 3m+n^2
# $$

# %%
valores = {m: sp.Rational(1, 2), n: sp.Rational(2, 3), p: -sp.Rational(1, 3)}

# %%
expr_raw = r" 3m+n^2"
expr = 3 * m + n**2

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  3m+n^2 \,= \, \frac{35}{18}$

# %% [markdown]
# $$
# \frac{n+2}{p}
# $$

# %%
expr_raw = r" \frac{n+2}{p} "
expr = (n + 2) / (p)

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  \frac{n+2}{p}  \,= \, -8$

# %% [markdown]
# $$
# mnp + p^2
# $$

# %%
expr_raw = r" mnp + p^2 "
expr = m * n * p + p**2

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  mnp + p^2  \,= \, 0$

# %% [markdown]
# ## Video 90
# ### VALOR NUMÉRICO de una expresión algebraica, Con FRACCIONES
#
# Dados los valores de las variables:
#
# $ m=\frac{1}{2}, n=\frac{2}{3}, p=-\frac{1}{3}$
#
# calcular las siguientes expresiones:
#
# $$
# (3m + 2n)(m - 2p)
# $$

# %%
expr_raw = r"(3m + 2n)(m - 2p) "
expr = (3 * m + 2 * n) * (m - 2 * p)

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle (3m + 2n)(m - 2p)  \,= \, \frac{119}{36}$

# %% [markdown]
# $$
# \frac{n+2}{p} + \frac{3}{m}
# $$

# %%
expr_raw = r"\frac{n+2}{p} + \frac{3}{m}"
expr = (n + 2) / p + 3 / m

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle \frac{n+2}{p} + \frac{3}{m} \,= \, -2$

# %% [markdown]
# $$
# \sqrt{-16mnp}
# $$

# %%
expr_raw = r"\sqrt{-16mnp}"
expr = sp.sqrt(-sp.Integer(16) * m * n * p)

result = expr.subs(valores)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle \sqrt{-16mnp} \,= \, \frac{4}{3}$

# %% [markdown]
# ## Video 91
# ###  ¿Qué son los Términos Semejantes?
#
# Los términos semejantes son los que tienen las mismas variables con los mismos exponentes
#
# $$
# a^2 + a^2 = 2a^2
# $$
#
# $$
# 3a^2b + 2a^2b = 5a^2b
# $$

# %% [markdown]
# ## Video 92
# ###  Reducción de términos semejantes
#
# $$
# 4m +3n -7m + 5n
# $$

# %%
expr_raw = r" 4m +3n -7m + 5n "
expr = 4 * m + 3 * n - 7 * m + 5 * n

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(expr)}"))
# Out:
# $\displaystyle  4m +3n -7m + 5n  \,= \, - 3 m + 8 n$

# %% [markdown]
# $$
# a^2b  -3ab^2 -ab^2 +2a^2b +5a^2b^2
# $$

# %%
expr_raw = r"a^2b  -3ab^2 -ab^2 +2a^2b +5a^2b^2 "
expr = a**2 * b - 3 * a * b**2 - a * b**2 + 2 * a**2 * b + 5 * a**2 * b**2

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(expr)}"))
# Out:
# $\displaystyle a^2b  -3ab^2 -ab^2 +2a^2b +5a^2b^2  \,= \, 5 a^{2} b^{2} + 3 a^{2} b - 4 a b^{2}$

# %% [markdown]
# $$
# 4xy +2xz -3xy +5xz -yz
# $$

# %%
expr_raw = r" 4xy +2xz -3xy +5xz -yz "
expr = 4 * x * y + 2 * x * z - 3 * x * y + 5 * x * z - y * z

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(expr)}"))
# Out:
# $\displaystyle  4xy +2xz -3xy +5xz -yz  \,= \, x y + 7 x z - y z$

# %% [markdown]
# $$
# 3x +2 -5x +4 -2x +1
# $$

# %%
expr_raw = r" 3x +2 -5x +4 -2x +1 "
expr = 3 * x + 2 - 5 * x + 4 - 2 * x + 1

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(expr)}"))
# Out:
# $\displaystyle  3x +2 -5x +4 -2x +1  \,= \, 7 - 4 x$

# %% [markdown]
# ## Video 93
# ###  Qué es un término algebraico, grado, coeficiente, monomio, binomio, trinomio, polinomio
#
# <img src="../../pics/conceptos_algebra.png" width=600>

# %%
expr_raw = r" 4m +3n -7m + 5n "
expr = 4 * m + 3 * n - 7 * m + 5 * n

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(expr)}"))
# Out:
# $\displaystyle  4m +3n -7m + 5n  \,= \, - 3 m + 8 n$

# %% [markdown]
# #### Monomio:
#
# 1 término algebraico
#
# $$2mn$$

# %% [markdown]
# #### Binomio:
#
# 2 términos algebraicos
#
# $$-3x +4y$$
#
# $$a +2$$

# %% [markdown]
# #### Trinomio:
#
# 3 términos algebraicos
#
# $$a + b +c $$
#
# $$-2x +5y^2 -1 $$

# %% [markdown]
# #### Polinomio:
#
# Cualquier cantidad de términos algebraicos
#
# $$ 1 +a +a^2 + a^3 $$
#
# $$2x +3y -5z^2 +2xy -4 +x^3 $$

# %% [markdown]
# ## Video 94
# ###  Suma de polinomios
#
# $$
# 3x +2y -3; \;\;\; 4y -2x +2; \;\;\; -5x -1 +2y
# $$

# %%
expr_raw = r" (3x +2y -3) + (4y -2x +2) + (-5x -1 +2y) "
pol1 = 3 * x + 2 * y - 3
pol2 = 4 * y - 2 * x + 2
pol3 = -5 * x - 1 + 2 * y

result = pol1 + pol2 + pol3


display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (3x +2y -3) + (4y -2x +2) + (-5x -1 +2y)  \,= \, - 4 x + 8 y - 2$

# %% [markdown]
# ## Video 95
# ###  Suma de polinomios, con dos variables
#
# $$
# 3mn +2m -5n; \;\;\; -3m +n -2mn; \;\;\; 3n +m +5mn
# $$

# %%
expr_raw = r" (3mn +2m -5n) + (-3m +n -2mn) + (3n +m +5mn) "
pol1 = 3 * m * n + 2 * m - 5 * n
pol2 = -3 * m + n - 2 * m * n
pol3 = 3 * n + m + 5 * m * n

result = pol1 + pol2 + pol3


display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (3mn +2m -5n) + (-3m +n -2mn) + (3n +m +5mn)  \,= \, 6 m n - n$

# %% [markdown]
# ## Video 98
# ###  Suma de polinomios CON FRACCIONES
#
# $$
# \frac{2}{3}x -\frac{1}{3}y +\frac{3}{5}z; \;\;\; \frac{1}{2}x - \frac{1}{2}y +3z; \;\;\; -\frac{3}{4}x +y +\frac{2}{5}z
# $$

# %%
expr_raw = r" (\frac{2}{3}x -\frac{1}{3}y +\frac{3}{5}z) + (\frac{1}{2}x - \frac{1}{2}y +3z) +(-\frac{3}{4}x +y +\frac{2}{5}z) "
pol1 = sp.Rational(2, 3) * x - sp.Rational(1, 3) * y + sp.Rational(3, 5) * z
pol2 = sp.Rational(1, 2) * x - sp.Rational(1, 2) * y + 3 * z
pol3 = -sp.Rational(3, 4) * x + y + sp.Rational(2, 5) * z

result = pol1 + pol2 + pol3
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (\frac{2}{3}x -\frac{1}{3}y +\frac{3}{5}z) + (\frac{1}{2}x - \frac{1}{2}y +3z) +(-\frac{3}{4}x +y +\frac{2}{5}z)  \,= \, \frac{5 x}{12} + \frac{y}{6} + 4 z$

# %% [markdown]
# ## Video 99
# ### Resta de polinomios
#
# $$
# (3x +2y -5) - (-4x +7y +2)
# $$

# %%
expr_raw = r" (3x +2y -5) - (-4x +7y +2) "
pol1 = 3 * x + 2 * y - 5
pol2 = -4 * x + 7 * y + 2

result = pol1 - pol2


display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (3x +2y -5) - (-4x +7y +2)  \,= \, 7 x - 5 y - 7$

# %% [markdown]
# ## Video 100
# ###  Resta de polinomios, con dos variables y exponentes
#
# $$
# (a^2b + 5ab^2 -7ab) - (2a^2b  +ab -3ab^2)
# $$

# %%
expr_raw = r" (a^2b + 5ab^2 -7ab) - (2a^2b  +ab -3ab^2) "
pol1 = a**2 * b + 5 * a * b**2 - 7 * a * b
pol2 = 2 * a**2 * b + a * b - 3 * a * b**2

result = pol1 - pol2


display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(result)}"))
# Out:
# $\displaystyle  (a^2b + 5ab^2 -7ab) - (2a^2b  +ab -3ab^2)  \,= \, - a^{2} b + 8 a b^{2} - 8 a b$
