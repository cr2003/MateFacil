# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
# C:\Users\crodr\Tutoriales\Math\MateFacil\pics\cover_curso_aritmetica.png
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# ## Aritmética Básica
#
# <img src="../../pics/cover_todo_fracciones.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX2wsPKMhI6rbeNj9gWppOGj

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\Tutoriales\\Math\\MateFacil\\Aritmetica_basica\\todo_fracciones'

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, x, y, z = sp.symbols("a, m, x, y, z", real=True)

spacing_equal = r"\,= \,"
spacing_approx = r"\, \approx \,"

# %% [markdown]
# #### Helper functions

# %%
def fmt(val, decimals=2):
    """Devuelve un entero si no tiene decimales, si tiene decimales los redondea a la cantidad pedida en decimals"""
    n = float(val)
    n = round(n, decimals)
    if n == int(n):
        return f"{int(n):,}"
    else:
        return f"{n:,.{decimals}f}"

# %%
def frac_mixta_to_frac(entero, frac):
    """
    Recibe un entero y una fraccion y devuelve una fraccion impropia.
    frac.p es el numerador de la fraccion
    frac.q es el denominador de la fraccion
    """
    numerador = (frac.q * entero) + frac.p
    denominador = frac.q
    return sp.Rational(numerador, denominador)

# %%
def frac_to_frac_mixta(frac):
    """
    Recibe una fraccion impropia y devuelve una cadena que representa una fraccion mixta
    """
    # Extraemos p y q
    p = frac.p
    q = frac.q

    # Calculamos la parte mixta
    entero = p // q
    residuo = p % q

    # Formateamos para mostrar
    if residuo == 0:
        resultado = rf"{entero}"
    else:
        if entero == 0:
            resultado = rf"\frac{{{residuo}}}{{{q}}}"
        else:
            resultado = rf"{entero} \frac{{{residuo}}}{{{q}}}"
    return resultado

# %% [markdown]
# ## Video 101
#
# ### Cómo sacar Raíz Cúbica de una Fracción
#
# $$ \sqrt[3]{\frac{1}{27}} $$

# %%
expr_raw = r" \sqrt[3]{\frac{1}{27}}"
frac = sp.root(sp.Rational(1, 27), 3)
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \sqrt[3]{\frac{1}{27}} \,= \, \frac{1}{3} \,= \, \frac{1}{3}$

# %% [markdown]
# ## Video 102
#
# ### Cómo sacar Raíz Cúbica de una Fracción
#
# $$ \sqrt[3]{\frac{8}{125}} $$

# %%
expr_raw = r" \sqrt[3]{\frac{8}{125}} "
frac = sp.root(sp.Rational(8, 125), 3)
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \sqrt[3]{\frac{8}{125}}  \,= \, \frac{2}{5} \,= \, \frac{2}{5}$

# %% [markdown]
# ## Video 103
#
# ### Cómo se calcula la Raíz Cuarta de una Fracción
#
# $$ \sqrt[4]{\frac{16}{625}} $$

# %%
expr_raw = r" \sqrt[4]{\frac{16}{625}} "
frac = sp.root(sp.Rational(16, 625), 4)
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \sqrt[4]{\frac{16}{625}}  \,= \, \frac{2}{5} \,= \, \frac{2}{5}$

# %% [markdown]
# ## Video 104
#
# ### Fracciones con exponente fraccionario
#
# $$ \left( \frac{9}{4} \right)^{\frac{1}{2}} $$

# %%
expr_raw = r" \left( \frac{9}{4} \right)^{\frac{1}{2}} "
frac = sp.Rational(9, 4) ** (sp.Rational(1, 2))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left( \frac{9}{4} \right)^{\frac{1}{2}}  \,= \, \frac{3}{2} \,= \, 1 \frac{1}{2}$

# %% [markdown]
# ### Fracciones con exponente fraccionario
#
# $$ \left( \frac{36}{16} \right)^{\frac{1}{2}} $$

# %%
expr_raw = r" \left( \frac{36}{16} \right)^{\frac{1}{2}}  "
frac = sp.Rational(36, 16) ** (sp.Rational(1, 2))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left( \frac{36}{16} \right)^{\frac{1}{2}}   \,= \, \frac{3}{2} \,= \, 1 \frac{1}{2}$

# %% [markdown]
# ### Fracciones con exponente fraccionario
#
# $$ \left( \frac{8}{27} \right)^{\frac{2}{3}} $$

# %%
expr_raw = r" \left( \frac{8}{27} \right)^{\frac{2}{3}} "
frac = sp.Rational(8, 27) ** (sp.Rational(2, 3))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left( \frac{8}{27} \right)^{\frac{2}{3}}  \,= \, \frac{4}{9} \,= \, \frac{4}{9}$

# %% [markdown]
# ## Video 105
#
# ### Fracciones con exponente fraccionario negativo
#
# $$ \left( \frac{8}{27} \right)^{-\frac{2}{3}} $$

# %%
expr_raw = r" \left( \frac{8}{27} \right)^{-\frac{2}{3}} "
frac = sp.Rational(8, 27) ** -(sp.Rational(2, 3))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left( \frac{8}{27} \right)^{-\frac{2}{3}}  \,= \, \frac{9}{4} \,= \, 2 \frac{1}{4}$

# %% [markdown]
# ### Fracciones con exponente fraccionario negativo
#
# $$ \left( \frac{25}{49} \right)^{-\frac{3}{2}} $$

# %%
expr_raw = r" \left( \frac{25}{49} \right)^{-\frac{3}{2}} "
frac = sp.Rational(25, 49) ** -(sp.Rational(3, 2))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left( \frac{25}{49} \right)^{-\frac{3}{2}}  \,= \, \frac{343}{125} \,= \, 2 \frac{93}{125}$

# %% [markdown]
# ## Video 106
#
# ### Cómo convertir a decimal una fracción
#
# $$ \frac{1}{2} $$

# %%
expr_raw = r" \frac{1}{2}  "
frac = sp.Rational(1, 2)
decimal = frac.evalf()
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(decimal)}"))
# Out:
# $\displaystyle  \frac{1}{2}   \,= \, 0.5$

# %% [markdown]
# ### Cómo convertir a decimal una fracción
#
# $$ \frac{3}{4} $$

# %%
expr_raw = r" \frac{3}{4}  "
frac = sp.Rational(3, 4)
decimal = frac.evalf()
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(decimal)}"))
# Out:
# $\displaystyle  \frac{3}{4}   \,= \, 0.75$

# %% [markdown]
# ### Cómo convertir a decimal una fracción
#
# $$ \frac{1}{3} $$

# %%
expr_raw = r" \frac{1}{3}  "
frac = sp.Rational(1, 3)
decimal = frac.evalf()
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(decimal)}"))
# Out:
# $\displaystyle  \frac{1}{3}   \,= \, 0.333333333333333$

# %% [markdown]
# ### Cómo convertir a decimal una fracción
#
# $$ \frac{1}{7} $$

# %%
expr_raw = r" \frac{1}{7}  "
frac = sp.Rational(1, 7)
decimal = frac.evalf()
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(decimal)}"))
# Out:
# $\displaystyle  \frac{1}{7}   \,= \, 0.142857142857143$

# %% [markdown]
# ## Video 107
#
# ### Fracción impropia a número decimal
#
# $$ \frac{5}{4} $$

# %%
expr_raw = r" \frac{5}{4}  "
frac = sp.Rational(5, 4)
decimal = frac.evalf()
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(decimal)}"))
# Out:
# $\displaystyle  \frac{5}{4}   \,= \, 1.25$

# %% [markdown]
# ## Video 111
#
# ### Fracción mixta a número decimal
#
# $$ 5\frac{3}{5} $$

# %%
expr_raw = r" 5\frac{3}{5}  "
frac = 5 + sp.Rational(3, 5)
decimal = frac.evalf()
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(decimal)}"))
# Out:
# $\displaystyle  5\frac{3}{5}   \,= \, 5.6$

# %% [markdown]
# ## Video 113
#
# ### Convertir fracción a porcentaje y viceversa
#
# $$ \frac{3}{4} $$

# %%
expr_raw = r" \frac{3}{4}  "
frac = sp.Rational(3, 4)
decimal = frac.evalf()
porcentaje = decimal * 100
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(decimal)} {spacing_equal} {fmt(porcentaje)}\% "
    )
)
# Out:
# $\displaystyle  \frac{3}{4}   \,= \, 0.75 \,= \, 75\% $

# %% [markdown]
# ### Convertir porcentaje a decimal y a fracción
#
# $$ 45\% $$

# %%
expr_raw = r"  45\%   "
porcentaje = 45
decimal = porcentaje / 100
frac = sp.Rational(porcentaje, 100)
decimal = frac.evalf()

display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(decimal)} {spacing_equal} {sp.latex(frac)}"
    )
)
# Out:
# $\displaystyle   45\%    \,= \, 0.45 \,= \, \frac{9}{20}$

# %% [markdown]
# ## Video 120
#
# ###  Resumen de fracciones: suma, resta, multiplicación y división de fracciones con signo
#
# $$\frac{2}{5} + \frac{1}{5}$$

# %%
expr_raw = r"\frac{2}{5} + \frac{1}{5}"
frac = sp.Rational(2, 5) + sp.Rational(1, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{2}{5} + \frac{1}{5} \,= \, \frac{3}{5}$

# %% [markdown]
# $$\frac{1}{3} - \frac{2}{5}$$

# %%
expr_raw = r"\frac{1}{3} - \frac{2}{5}"
frac = sp.Rational(1, 3) - sp.Rational(2, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{1}{3} - \frac{2}{5} \,= \, - \frac{1}{15}$

# %% [markdown]
# $$ -\frac{1}{2} - \frac{2}{3} $$

# %%
expr_raw = r" -\frac{1}{2} - \frac{2}{3} "
frac = -sp.Rational(1, 2) - sp.Rational(2, 3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  -\frac{1}{2} - \frac{2}{3}  \,= \, - \frac{7}{6}$

# %% [markdown]
# $$ - \frac{3}{4} + \frac{1}{3}$$

# %%
expr_raw = r"- \frac{3}{4} + \frac{1}{3}"
frac = -sp.Rational(3, 4) + sp.Rational(1, 3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle - \frac{3}{4} + \frac{1}{3} \,= \, - \frac{5}{12}$

# %% [markdown]
# $$ \frac{2}{3} - 2 $$

# %%
expr_raw = r"\frac{2}{3} - 2"
frac = sp.Rational(2, 3) - 2
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{2}{3} - 2 \,= \, - \frac{4}{3}$

# %% [markdown]
# $$ \frac{1}{2} + \frac{2}{3} - \frac{3}{4} $$

# %%
expr_raw = r" \frac{1}{2} + \frac{2}{3} - \frac{3}{4}"
frac = sp.Rational(1, 2) + sp.Rational(2, 3) - sp.Rational(3, 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  \frac{1}{2} + \frac{2}{3} - \frac{3}{4} \,= \, \frac{5}{12}$

# %% [markdown]
# ### multiplicación
#
# $$ \frac{2}{3} \left( \frac{4}{5} \right)$$

# %%
expr_raw = r"\frac{2}{3} \left( \frac{4}{5} \right)"
frac = sp.Rational(2, 3) * sp.Rational(4, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{2}{3} \left( \frac{4}{5} \right) \,= \, \frac{8}{15}$

# %% [markdown]
# $$ - \frac{2}{3} \left( \frac{1}{4} \right)$$

# %%
expr_raw = r"- \frac{2}{3} \left( \frac{1}{4} \right)"
frac = -sp.Rational(2, 3) * sp.Rational(1, 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle - \frac{2}{3} \left( \frac{1}{4} \right) \,= \, - \frac{1}{6}$

# %% [markdown]
# $$ - 4 \left( - \frac{2}{3} \right)$$

# %%
expr_raw = r"- 4 \left( - \frac{2}{3} \right)"
frac = -4 * -sp.Rational(2, 3)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle - 4 \left( - \frac{2}{3} \right) \,= \, \frac{8}{3}$

# %% [markdown]
# $$ \frac{2}{3} \left( -\frac{1}{2} \right) \left( \frac{2}{5} \right)$$

# %%
expr_raw = r"\frac{2}{3} \left( -\frac{1}{2} \right) \left( \frac{2}{5} \right)"
frac = sp.Rational(2, 3) * -sp.Rational(1, 2) * sp.Rational(2, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{2}{3} \left( -\frac{1}{2} \right) \left( \frac{2}{5} \right) \,= \, - \frac{2}{15}$

# %% [markdown]
# ### división
#
# $$ \frac{10}{2} $$

# %%
expr_raw = r"\frac{10}{2}"
frac = sp.Rational(10, 2)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{10}{2} \,= \, 5$

# %% [markdown]
# $$ \frac{\frac{2}{3}}{\frac{1}{4}}  = \frac{2}{3} \div \frac{1}{4}$$

# %%
expr_raw = r"\frac{2}{3} \div \frac{1}{4}"
frac = sp.Rational(2, 3) / sp.Rational(1, 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{2}{3} \div \frac{1}{4} \,= \, \frac{8}{3}$

# %% [markdown]
# $$ -\frac{3}{5} \div \frac{2}{7}$$

# %%
expr_raw = r" -\frac{3}{5} \div \frac{2}{7}"
frac = -sp.Rational(3, 5) / sp.Rational(2, 7)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  -\frac{3}{5} \div \frac{2}{7} \,= \, - \frac{21}{10}$

# %% [markdown]
# ## Video 121
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \frac{2}{3} + \frac{1}{2} \left( -\frac{3}{5} \right) $$

# %%
expr_raw = r" \frac{2}{3} + \frac{1}{2} \left( -\frac{3}{5} \right) "
frac = sp.Rational(2, 3) + sp.Rational(1, 2) * -sp.Rational(3, 5)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  \frac{2}{3} + \frac{1}{2} \left( -\frac{3}{5} \right)  \,= \, \frac{11}{30}$

# %% [markdown]
# $$\left( 2 + \frac{1}{2} \right)  \left(\frac{1}{3} -2 \right)$$

# %%
expr_raw = r" \left( 2 + \frac{1}{2} \right)  \left(\frac{1}{3} -2 \right) "
frac = (2 + sp.Rational(1, 2)) * (sp.Rational(1, 3) - 2)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  \left( 2 + \frac{1}{2} \right)  \left(\frac{1}{3} -2 \right)  \,= \, - \frac{25}{6}$

# %% [markdown]
# ## Video 122
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ 2 - \left( \frac{1}{2} \right) \left( \frac{2}{3} \right) - \frac{3}{4}$$

# %%
expr_raw = r" 2 - \left( \frac{1}{2} \right) \left( \frac{2}{3} \right) - \frac{3}{4} "
frac = 2 - (sp.Rational(1, 2)) * (sp.Rational(2, 3)) - sp.Rational(3, 4)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  2 - \left( \frac{1}{2} \right) \left( \frac{2}{3} \right) - \frac{3}{4}  \,= \, \frac{11}{12}$

# %% [markdown]
# $$ \frac{3}{5} \left( \frac{1}{2} - \frac{2}{3} \right) + \frac{1}{2}$$

# %%
expr_raw = r" \frac{3}{5} \left( \frac{1}{2} - \frac{2}{3} \right) + \frac{1}{2} "
frac = sp.Rational(3, 5) * (sp.Rational(1, 2) - sp.Rational(2, 3)) + sp.Rational(1, 2)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  \frac{3}{5} \left( \frac{1}{2} - \frac{2}{3} \right) + \frac{1}{2}  \,= \, \frac{2}{5}$

# %% [markdown]
# ## Video 123
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \left( 1 + \frac{3}{4} \right) \div \left( \frac{2}{3} +  \frac{1}{5} \right)$$

# %%
expr_raw = (
    r" \left( 1 + \frac{3}{4} \right) \div \left( \frac{2}{3} +  \frac{1}{5} \right) "
)
frac = (1 + sp.Rational(3, 4)) / (sp.Rational(2, 3) + sp.Rational(1, 5))
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  \left( 1 + \frac{3}{4} \right) \div \left( \frac{2}{3} +  \frac{1}{5} \right)  \,= \, \frac{105}{52}$

# %% [markdown]
# ## Video 124
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \left( 1 - \frac{1}{2} + \frac{3}{4} \right) \div \left( \frac{2}{5} -  \frac{1}{8} \right)$$

# %%
expr_raw = r" \left( 1 - \frac{1}{2} + \frac{3}{4} \right) \div \left( \frac{2}{5} -  \frac{1}{8} \right)"
frac = (1 - sp.Rational(1, 2) + sp.Rational(3, 4)) / (
    sp.Rational(2, 5) - sp.Rational(1, 8)
)
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  \left( 1 - \frac{1}{2} + \frac{3}{4} \right) \div \left( \frac{2}{5} -  \frac{1}{8} \right) \,= \, \frac{50}{11}$

# %% [markdown]
# ## Video 125
#
# ###  Fracciones con paréntesis: suma, resta, multiplicación y división
#
# $$ \left( \frac{4}{5} - \frac{1}{2} \right) - \left( \frac{1}{3} +  \frac{1}{6} \right) $$

# %%
expr_raw = r" \left( \frac{4}{5} - \frac{1}{2} \right) - \left( \frac{1}{3} +  \frac{1}{6} \right) "
frac = (sp.Rational(4, 5) - sp.Rational(1, 2)) - (sp.Rational(1, 3) + sp.Rational(1, 6))
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle  \left( \frac{4}{5} - \frac{1}{2} \right) - \left( \frac{1}{3} +  \frac{1}{6} \right)  \,= \, - \frac{1}{5}$
