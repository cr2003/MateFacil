# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
# C:\Users\crodr\Tutoriales\Math\MateFacil\pics\cover_curso_aritmetica.png
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# ## Aritmética Básica
#
# <img src="../../pics/cover_todo_fracciones.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX2wsPKMhI6rbeNj9gWppOGj

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\Tutoriales\\Math\\MateFacil\\Aritmetica_basica\\todo_fracciones'

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, x, y, z = sp.symbols("a, m, x, y, z", real=True)

spacing_equal = r"\,= \,"
spacing_approx = r"\, \approx \,"

# %% [markdown]
# #### Helper functions

# %%
def fmt(val, decimals=2):
    """Devuelve un entero si no tiene decimales, si tiene decimales los redondea a la cantidad pedida en decimals"""
    n = float(val)
    n = round(n, decimals)
    if n == int(n):
        return f"{int(n):,}"
    else:
        return f"{n:,.{decimals}f}"

# %%
def frac_mixta_to_frac(entero, frac):
    """
    Recibe un entero y una fraccion y devuelve una fraccion impropia.
    frac.p es el numerador de la fraccion
    frac.q es el denominador de la fraccion
    """
    numerador = (frac.q * entero) + frac.p
    denominador = frac.q
    return sp.Rational(numerador, denominador)

# %%
def frac_to_frac_mixta(frac):
    """
    Recibe una fraccion impropia y devuelve una cadena que representa una fraccion mixta
    """
    # Extraemos p y q
    p = frac.p
    q = frac.q

    # Calculamos la parte mixta
    entero = p // q
    residuo = p % q

    # Formateamos para mostrar
    if residuo == 0:
        resultado = rf"{entero}"
    else:
        if entero == 0:
            resultado = rf"\frac{{{residuo}}}{{{q}}}"
        else:
            resultado = rf"{entero} \frac{{{residuo}}}{{{q}}}"
    return resultado

# %% [markdown]
# ## Video 51
#
# ### Suma de fracciones mixtas
#
# $$ 3 \frac{1}{2} + 4 \frac{2}{3} $$

# %%
expr_raw = r"3 \frac{1}{2} + 4 \frac{2}{3}"
frac = (3 + sp.Rational(1, 2)) + (4 + sp.Rational(2, 3))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle 3 \frac{1}{2} + 4 \frac{2}{3} \,= \, \frac{49}{6} \,= \, 8 \frac{1}{6}$

# %% [markdown]
# ## Video 52
#
# ### Suma de fracciones mixtas
#
# $$ 2 \frac{3}{4} + 1 \frac{3}{5} $$

# %%
expr_raw = r"2 \frac{3}{4} + 1 \frac{3}{5} "
frac = (2 + sp.Rational(3, 4)) + (1 + sp.Rational(3, 5))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle 2 \frac{3}{4} + 1 \frac{3}{5}  \,= \, \frac{87}{20} \,= \, 4 \frac{7}{20}$

# %% [markdown]
# ## Video 53
#
# ### Resta de fracciones mixtas
#
# $$ 2 \frac{1}{4} - 1 \frac{5}{6} $$

# %%
expr_raw = r"2 \frac{1}{4} - 1 \frac{5}{6}"
frac = (2 + sp.Rational(1, 4)) - (1 + sp.Rational(5, 6))
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)} "))
# Out:
# $\displaystyle 2 \frac{1}{4} - 1 \frac{5}{6} \,= \, \frac{5}{12} $

# %% [markdown]
# ## Video 54
#
# ### Resta de fracciones mixtas
#
# $$ 3 \frac{4}{5} - 2 \frac{1}{3} $$

# %%
expr_raw = r"3 \frac{4}{5} - 2 \frac{1}{3}"
frac = (3 + sp.Rational(4, 5)) - (2 + sp.Rational(1, 3))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle 3 \frac{4}{5} - 2 \frac{1}{3} \,= \, \frac{22}{15} \,= \, 1 \frac{7}{15}$

# %% [markdown]
# ## Video 55
#
# ### Suma de una fracción mixta y una fracción propia
#
# $$ 4 \frac{2}{3} + \frac{3}{5} $$

# %%
expr_raw = r" 4 \frac{2}{3} + \frac{3}{5}"
frac = (4 + sp.Rational(2, 3)) + (+sp.Rational(3, 5))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  4 \frac{2}{3} + \frac{3}{5} \,= \, \frac{79}{15} \,= \, 5 \frac{4}{15}$

# %% [markdown]
# ## Video 56
#
# ### Suma de una fracción mixta y una fracción propia
#
# $$ 3 \frac{4}{5} + \frac{1}{7} $$

# %%
expr_raw = r" 3 \frac{4}{5} + \frac{1}{7}"
frac = (3 + sp.Rational(4, 5)) + (sp.Rational(1, 7))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  3 \frac{4}{5} + \frac{1}{7} \,= \, \frac{138}{35} \,= \, 3 \frac{33}{35}$

# %% [markdown]
# ## Video 57
#
# ### Suma de una fracción mixta y una fracción propia
#
# $$ 4 \frac{1}{2} + \frac{2}{9} $$

# %%
expr_raw = r" 4 \frac{1}{2} + \frac{2}{9}"
frac = (4 + sp.Rational(1, 2)) + (sp.Rational(2, 9))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  4 \frac{1}{2} + \frac{2}{9} \,= \, \frac{85}{18} \,= \, 4 \frac{13}{18}$

# %% [markdown]
# ## Video 58
#
# ### Suma de una fracción propia y una fracción mixta
#
# $$ \frac{1}{3} + 3\frac{2}{5} $$

# %%
expr_raw = r" \frac{1}{3} + 3\frac{2}{5}"
frac = (sp.Rational(1, 3)) + (3 + sp.Rational(2, 5))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \frac{1}{3} + 3\frac{2}{5} \,= \, \frac{56}{15} \,= \, 3 \frac{11}{15}$

# %% [markdown]
# ## Video 59
#
# ### Suma de una fracción propia y una fracción mixta
#
# $$ \frac{2}{7} + 6\frac{1}{4} $$

# %%
expr_raw = r" \frac{2}{7} + 6\frac{1}{4} "
frac = (sp.Rational(2, 7)) + (6 + sp.Rational(1, 4))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \frac{2}{7} + 6\frac{1}{4}  \,= \, \frac{183}{28} \,= \, 6 \frac{15}{28}$

# %% [markdown]
# ## Video 60
#
# ### Resta de una fracción mixta y una fracción propia
#
# $$ 2\frac{1}{6} - \frac{2}{5} $$

# %%
expr_raw = r" 2\frac{1}{6} - \frac{2}{5} "
frac = (2 + sp.Rational(1, 6)) - (sp.Rational(2, 5))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  2\frac{1}{6} - \frac{2}{5}  \,= \, \frac{53}{30} \,= \, 1 \frac{23}{30}$

# %% [markdown]
# ## Video 61
#
# ### Resta de una fracción mixta y una fracción propia
#
# $$ 7\frac{1}{2} - \frac{4}{5} $$

# %%
expr_raw = r" 7\frac{1}{2} - \frac{4}{5} "
frac = (7 + sp.Rational(1, 2)) - (sp.Rational(4, 5))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  7\frac{1}{2} - \frac{4}{5}  \,= \, \frac{67}{10} \,= \, 6 \frac{7}{10}$

# %% [markdown]
# ## Video 62
#
# ### Resta de una fracción mixta y una fracción propia
#
# $$ 1\frac{1}{6} - \frac{3}{4} $$

# %%
expr_raw = r" 1\frac{1}{6} - \frac{3}{4} "
frac = (1 + sp.Rational(1, 6)) - (sp.Rational(3, 4))
display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)} "))
# Out:
# $\displaystyle  1\frac{1}{6} - \frac{3}{4}  \,= \, \frac{5}{12} $

# %% [markdown]
# ## Video 63
#
# ### Suma de 3 fracciones
# $$ \frac{3}{4} + \frac{5}{2} + \frac{2}{6} $$

# %%
expr_raw = r" \frac{3}{4} + \frac{5}{2} + \frac{2}{6}  "
frac = sp.Rational(3, 4) + sp.Rational(5, 2) + sp.Rational(2, 6)
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \frac{3}{4} + \frac{5}{2} + \frac{2}{6}   \,= \, \frac{43}{12} \,= \, 3 \frac{7}{12}$

# %% [markdown]
# ### Suma y resta 3 fracciones
# $$ \frac{2}{5} + \frac{3}{2} - \frac{1}{10} $$

# %%
expr_raw = r" \frac{2}{5} + \frac{3}{2} - \frac{1}{10}  "
frac = sp.Rational(2, 5) + sp.Rational(3, 2) - sp.Rational(1, 10)
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \frac{2}{5} + \frac{3}{2} - \frac{1}{10}   \,= \, \frac{9}{5} \,= \, 1 \frac{4}{5}$

# %% [markdown]
# ## Video 72
#
# ### Suma de 3 fracciones, dos mixtas una propia
#
# $$ 1 \frac{1}{3} + 2 \frac{3}{5} + \frac{2}{15}$$

# %%
expr_raw = r"1 \frac{1}{3} + 2 \frac{3}{5} + \frac{2}{15} "
frac = (1 + sp.Rational(1, 3)) + (2 + sp.Rational(3, 5)) + (sp.Rational(2, 15))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle 1 \frac{1}{3} + 2 \frac{3}{5} + \frac{2}{15}  \,= \, \frac{61}{15} \,= \, 4 \frac{1}{15}$

# %% [markdown]
# ## Video 81
#
# ### Multiplicación de fracción propia, mixta y número entero
#
# $$ \frac{5}{6} \times 4\frac{1}{2} \times 12 $$

# %%
expr_raw = r" \frac{5}{6} \times 4\frac{1}{2} \times 12  "
frac = (sp.Rational(5, 6)) * (4 + sp.Rational(1, 2)) * 12
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \frac{5}{6} \times 4\frac{1}{2} \times 12   \,= \, 45 \,= \, 45$

# %% [markdown]
# ## Video 85
#
# ### División de un entero con una fracción impropia
#
# $$ 5 \div \frac{4}{3} $$

# %%
expr_raw = r"5 \div \frac{4}{3} "
frac = 5 / (sp.Rational(4, 3))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle 5 \div \frac{4}{3}  \,= \, \frac{15}{4} \,= \, 3 \frac{3}{4}$

# %% [markdown]
# ## Video 90
#
# ### División de fracción propia entre fracción mixta
#
# $$  \frac{2}{3} \div 7\frac{1}{2} $$

# %%
expr_raw = r"\frac{2}{3} \div 7\frac{1}{2} "
frac = (sp.Rational(2, 3)) / (7 + sp.Rational(1, 2))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle \frac{2}{3} \div 7\frac{1}{2}  \,= \, \frac{4}{45} \,= \, \frac{4}{45}$

# %% [markdown]
# ## Video 97
#
# ### Fracciones con exponente
#
# $$ \left(\frac{3}{4}\right)^2 $$

# %%
expr_raw = r" \left(\frac{3}{4}\right)^2"
frac = (sp.Rational(3, 4)) ** 2
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left(\frac{3}{4}\right)^2 \,= \, \frac{9}{16} \,= \, \frac{9}{16}$

# %% [markdown]
# ### Fracciones con exponente
#
# $$ \left(\frac{1}{2}\right)^4 $$

# %%
expr_raw = r" \left(\frac{1}{2}\right)^4 "
frac = (sp.Rational(1, 2)) ** 4
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left(\frac{1}{2}\right)^4  \,= \, \frac{1}{16} \,= \, \frac{1}{16}$

# %% [markdown]
# ### Fracciones con exponente
#
# $$ \left(\frac{9}{21}\right)^0 $$

# %%
expr_raw = r" \left(\frac{9}{21}\right)^0  "
frac = (sp.Rational(9, 21)) ** 0
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left(\frac{9}{21}\right)^0   \,= \, 1 \,= \, 1$

# %% [markdown]
# ## Video 98
#
# ### Fracciones con exponente negativo
#
# $$ \left(\frac{2}{3}\right)^{-3} $$

# %%
expr_raw = r" \left(\frac{2}{3}\right)^{-3}"
frac = (sp.Rational(2, 3)) ** -3
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \left(\frac{2}{3}\right)^{-3} \,= \, \frac{27}{8} \,= \, 3 \frac{3}{8}$

# %% [markdown]
# ## Video 99
#
# ### Cómo sacar Raíz Cuadrada de una Fracción
#
# $$ \sqrt{\frac{16}{9}} $$

# %%
expr_raw = r" \sqrt{\frac{16}{9}}"
frac = sp.sqrt(sp.Rational(16, 9))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \sqrt{\frac{16}{9}} \,= \, \frac{4}{3} \,= \, 1 \frac{1}{3}$

# %% [markdown]
# ## Video 100
#
# ### Cómo sacar Raíz Cuadrada de una Fracción
#
# $$ \sqrt{\frac{36}{49}} $$

# %%
expr_raw = r" \sqrt{\frac{36}{49}}"
frac = sp.sqrt(sp.Rational(36, 49))
display(
    Math(
        rf"{expr_raw} {spacing_equal} {sp.latex(frac)} {spacing_equal} {frac_to_frac_mixta(frac)}"
    )
)
# Out:
# $\displaystyle  \sqrt{\frac{36}{49}} \,= \, \frac{6}{7} \,= \, \frac{6}{7}$
