# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
# C:\Users\crodr\Tutoriales\Math\MateFacil\pics\cover_curso_aritmetica.png
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# <img src="../../pics/cover_multiplicacion.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX0AYWz4wqwzitlfoSn5vdP4

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\Tutoriales\\Math\\MateFacil\\Aritmetica_basica\\multiplicación'

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, x, y, z = sp.symbols("a, m, x, y, z", real=True)

spacing = r"\,= \,"

# %% [markdown]
# ## Video 1
#
# ### Cómo Multiplicar
#
# $$5,216 \times 4 $$

# %%
expr_raw = r"5,216 \times 4"
num = 5216 * 4
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle 5,216 \times 4 \,= \, \mathtt{\text{20,864}}$

# %% [markdown]
# ## Video 2
#
# ### Cómo Multiplicar
#
# $$ 16,349 \times 8$$

# %%
expr_raw = r"16,349 \times 8 "
num = 16349 * 8
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle 16,349 \times 8  \,= \, \mathtt{\text{130,792}}$

# %% [markdown]
# ## Video 3
#
# ### Cómo Multiplicar
#
# $$3,477 \times 27 $$

# %%
expr_raw = r"3,477 \times 27"
num = 3477 * 27
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle 3,477 \times 27 \,= \, \mathtt{\text{93,879}}$

# %% [markdown]
# ## Video 4
#
# ### Cómo Multiplicar
#
# $$73,914 \times 83 $$

# %%
expr_raw = r"73,914 \times 83"
num = 73914 * 83
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle 73,914 \times 83 \,= \, \mathtt{\text{6,134,862}}$

# %% [markdown]
# ## Video 5
#
# ### Cómo Multiplicar
#
# $$26,715 \times 317 $$

# %%
expr_raw = r"26,715 \times 317 "
num = 26715 * 317
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle 26,715 \times 317  \,= \, \mathtt{\text{8,468,655}}$

# %% [markdown]
# ## Video 5
#
# ### Cómo Multiplicar
#
# $$ 723,190 \times 529 $$

# %%
expr_raw = r"723,190 \times 529"
num = 723190 * 529
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle 723,190 \times 529 \,= \, \mathtt{\text{382,567,510}}$

# %% [markdown]
# ## Video 9
#
# ### Cómo multiplicar números CON PUNTO DECIMAL
#
# $$ 14.25 \times 6 $$

# %%
expr_raw = r"14.25 \times 6"
num = 14.25 * 6
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle 14.25 \times 6 \,= \, \mathtt{\text{85.5}}$

# %% [markdown]
# ## Video 10
#
# ### Cómo multiplicar números CON PUNTO DECIMAL
#
# $$ 3.128 \times 8 $$

# %%
expr_raw = r"3.128 \times 8"
num = 3.128 * 8
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle 3.128 \times 8 \,= \, \mathtt{\text{25.024}}$

# %% [markdown]
# ## Video 11
#
# ### Cómo multiplicar números CON PUNTO DECIMAL
#
# $$ 41.725 \times 3.9 $$

# %%
expr_raw = r" 41.72 \times 3.9"
num = 41.72 * 3.9
resultado = f"{num:,}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle  41.72 \times 3.9 \,= \, \mathtt{\text{162.708}}$

# %% [markdown]
# ## Video 12
#
# ### Cómo multiplicar números CON PUNTO DECIMAL
#
# $$ 4.429 \times 0.56 $$

# %%
expr_raw = r" 4.429 \times 0.56"
num = 4.429 * 0.56
resultado = f"{num:,.5f}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle  4.429 \times 0.56 \,= \, \mathtt{\text{2.48024}}$

# %% [markdown]
# ## Video 13
#
# ### Cómo multiplicar números CON PUNTO DECIMAL
#
# $$ 3.2785 \times 2.641 $$

# %%
expr_raw = r" 3.2785 \times 2.641"
num = 3.2785 * 2.641
resultado = f"{num:,.7f}"

display(Math(rf"{expr_raw} {spacing} {sp.latex(resultado)}"))
# Out:
# $\displaystyle  3.2785 \times 2.641 \,= \, \mathtt{\text{8.6585185}}$
