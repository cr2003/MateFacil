# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
# C:\Users\crodr\Tutoriales\Math\MateFacil\pics\cover_curso_aritmetica.png
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# ## Aritmética Básica
#
# <img src="../../pics/cover_sumas.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX1j-nhkWQA4H1rTLkFDAoiR

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\Tutoriales\\Math\\MateFacil\\Aritmetica_basica\\sumas'

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, x, y, z = sp.symbols("a, m, x, y, z", real=True)

spacing_equal = r"\,= \,"
spacing_approx = r"\, \approx \,"

# %% [markdown]
# #### Helper functions

# %%
def fmt(val, decimals=2):
    """Devuelve un entero si no tiene decimales, si tiene decimales los redondea a la cantidad pedida en decimals"""
    n = float(val)
    n = round(n, decimals)
    if n == int(n):
        return f"{int(n):,}"
    else:
        return f"{n:,.{decimals}f}"

# %% [markdown]
# ## Video 1
#
# ### Cómo sumar 3 números y cómo acomodarlos correctamente
#
# $$3,081 + 56 + 310$$

# %%
expr_raw = r"3,081 + 56 + 310"
addition = 3_081 + 56 + 310

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 3,081 + 56 + 310 \,= \, 3,447$

# %% [markdown]
# ## Video 2
#
# ### Cómo sumar 4 números y cómo acomodarlos correctamente
#
# $$12,187 + 1,722 + 301 + 45$$

# %%
expr_raw = r"12,187 + 1,722 + 301 + 45"
addition = 12_187 + 1_722 + 301 + 45

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 12,187 + 1,722 + 301 + 45 \,= \, 14,255$

# %% [markdown]
# ## Video 3
#
#
# ### Cómo sumar 5 números y cómo acomodarlos correctamente
#
# $$4,310 + 216 + 1,062 + 6 + 55$$

# %%
expr_raw = r"4,310 + 216 + 1,062 + 6 + 55"
addition = 4_310 + 216 + 1_062 + 6 + 55

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 4,310 + 216 + 1,062 + 6 + 55 \,= \, 5,649$

# %% [markdown]
# ## Video 4
#
# ### Cómo sumar 3 números CON PUNTO DECIMAL y cómo acomodarlos correctamente
#
# $$162.4 + 20.31 + 1.025$$

# %%
expr_raw = r"162.4 + 20.31 + 1.025"
addition = 162.4 + 20.31 + 1.025

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition, 3)}"))
# Out:
# $\displaystyle 162.4 + 20.31 + 1.025 \,= \, 183.735$

# %% [markdown]
# ## Video 5
#
# ### Cómo sumar 4 números CON PUNTO DECIMAL y cómo acomodarlos correctamente
#
# $$109.24 + 21.34 + 512 + 11.9$$

# %%
expr_raw = r"109.24 + 21.34 + 512 + 11.9"
addition = 109.24 + 21.34 + 512 + 11.9

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 109.24 + 21.34 + 512 + 11.9 \,= \, 654.48$

# %% [markdown]
# ## Video 6
#
# ### Cómo sumar 5 números CON PUNTO decimal MUY FÁCIL!! y cómo acomodarlos correctamente
#
# $$0.152 + 1.31 + 21.05 + 1.002 + 3.54$$

# %%
expr_raw = r"0.152 + 1.31 + 21.05 + 1.002 + 3.54"
addition = 0.152 + 1.31 + 21.05 + 1.002 + 3.54

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition, 3)}"))
# Out:
# $\displaystyle 0.152 + 1.31 + 21.05 + 1.002 + 3.54 \,= \, 27.054$

# %% [markdown]
# ## Video 7
#
# ### Cómo sumar números muy fácilmente
#
# $$ 51 + 27 $$

# %%
expr_raw = r"51 + 27"
addition = 51 + 27

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 51 + 27 \,= \, 78$

# %% [markdown]
# ### Cómo sumar números muy fácilmente
#
# $$435 + 67$$

# %%
expr_raw = r"435 + 67"
addition = 435 + 67

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 435 + 67 \,= \, 502$

# %% [markdown]
# ### Cómo sumar números muy fácilmente
#
# $$542 + 1,287 + 79$$

# %%
expr_raw = r"542 + 1,287 + 79"
addition = 542 + 1_287 + 79

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 542 + 1,287 + 79 \,= \, 1,908$

# %% [markdown]
# ### Realizar las siguientes sumas:
#
# $$56 + 33$$

# %%
expr_raw = r"56 + 33"
addition = 56 + 33

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 56 + 33 \,= \, 89$

# %% [markdown]
# ### Realizar las siguientes sumas:
#
# $$199 + 48$$

# %%
expr_raw = r"199 + 48"
addition = 199 + 48

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 199 + 48 \,= \, 247$

# %% [markdown]
# ### Realizar las siguientes sumas:
#
# $$1,278 + 367 + 1,523$$

# %%
expr_raw = r"1,278 + 367 + 1,523"
addition = 1_278 + 367 + 1_523

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 1,278 + 367 + 1,523 \,= \, 3,168$

# %% [markdown]
# ### Realizar las siguientes sumas:
#
# $$435 + 399$$

# %%
expr_raw = r"435 + 399"
addition = 435 + 399

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition)}"))
# Out:
# $\displaystyle 435 + 399 \,= \, 834$

# %% [markdown]
# ## Video 8
#
# ### Cómo sumar números con punto decimal
#
# $$ 12.56 + 677 + 1.003$$

# %%
expr_raw = r"12.56 + 677 + 1.003"
addition = 12.56 + 677 + 1.003

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition, 3)}"))
# Out:
# $\displaystyle 12.56 + 677 + 1.003 \,= \, 690.563$

# %% [markdown]
# ### Cómo sumar números con punto decimal
#
# $$ 452.13 + 66.56 + 229.669$$

# %%
expr_raw = r"452.13 + 66.56 + 229.669"
addition = 452.13 + 66.56 + 229.669

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition, 3)}"))
# Out:
# $\displaystyle 452.13 + 66.56 + 229.669 \,= \, 748.359$

# %% [markdown]
# ### Realizar las siguientes sumas:
#
# $$1.003 + 10.03 + 100.3 + 1,003$$

# %%
expr_raw = r"1.003 + 10.03 + 100.3 + 1,003"
addition = 1.003 + 10.03 + 100.3 + 1_003

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition, 3)}"))
# Out:
# $\displaystyle 1.003 + 10.03 + 100.3 + 1,003 \,= \, 1,114.333$

# %% [markdown]
# ### Realizar las siguientes sumas:
#
# $$23.67 + 134.77 + 132.331$$

# %%
expr_raw = r"23.67 + 134.77 + 132.331"
addition = 23.67 + 134.77 + 132.331

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition, 3)}"))
# Out:
# $\displaystyle 23.67 + 134.77 + 132.331 \,= \, 290.771$

# %% [markdown]
# ### Realizar las siguientes sumas:
#
# $$8,538.1 + 542.22 + 15.121$$

# %%
expr_raw = r"8,538.1 + 542.22 + 15.121"
addition = 8_538.1 + 542.22 + 15.121

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition, 3)}"))
# Out:
# $\displaystyle 8,538.1 + 542.22 + 15.121 \,= \, 9,095.441$

# %% [markdown]
# ### Realizar las siguientes sumas:
#
# $$8,827 + 12.1 + 255.2201 + 0.002$$

# %%
expr_raw = r"8,827 + 12.1 + 255.2201 + 0.002"
addition = 8_827 + 12.1 + 255.2201 + 0.002

display(Math(rf"{expr_raw} {spacing_equal} {fmt(addition, 4)}"))
# Out:
# $\displaystyle 8,827 + 12.1 + 255.2201 + 0.002 \,= \, 9,094.3221$
