# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
# C:\Users\crodr\Tutoriales\Math\MateFacil\pics\cover_curso_aritmetica.png
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# ## Aritmética Básica
#
# <img src="../../pics/cover_fracciones.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX2a8dAchPc6-jKoUMXjx9em

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\Tutoriales\\Math\\MateFacil\\Aritmetica_basica\\fracciones'

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, x, y, z = sp.symbols("a, m, x, y, z", real=True)

spacing_equal = r"\,= \,"
spacing_approx = r"\, \approx \,"

# %% [markdown]
# #### Helper functions

# %%
def fmt(val, decimals=2):
    """Devuelve un entero si no tiene decimales, si tiene decimales los redondea a la cantidad pedida en decimals"""
    n = float(val)
    n = round(n, decimals)
    if n == int(n):
        return f"{int(n):,}"
    else:
        return f"{n:,.{decimals}f}"

# %% [markdown]
# ## Video 1
#
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{16}{32}$$

# %%
expr_raw = r"\frac{16}{32}"
frac = sp.Rational(16, 32)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{16}{32} \,= \, \frac{1}{2}$

# %% [markdown]
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{12}{8}$$

# %%
expr_raw = r"\frac{12}{8}"
frac = sp.Rational(12, 8)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{12}{8} \,= \, \frac{3}{2}$

# %% [markdown]
# ## Video 2
#
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{36}{54}$$

# %%
expr_raw = r"\frac{36}{54}"
frac = sp.Rational(36, 54)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{36}{54} \,= \, \frac{2}{3}$

# %% [markdown]
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{72}{60}$$

# %%
expr_raw = r"\frac{72}{60}"
frac = sp.Rational(72, 60)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{72}{60} \,= \, \frac{6}{5}$

# %% [markdown]
# ## Video 3
#
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{35}{15}$$

# %%
expr_raw = r"\frac{35}{15}"
frac = sp.Rational(35, 15)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{35}{15} \,= \, \frac{7}{3}$

# %% [markdown]
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{20}{130}$$

# %%
expr_raw = r"\frac{20}{130}"
frac = sp.Rational(20, 130)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{20}{130} \,= \, \frac{2}{13}$

# %% [markdown]
# ## Video 4
#
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{60}{180}$$

# %%
expr_raw = r"\frac{60}{180}"
frac = sp.Rational(60, 180)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{60}{180} \,= \, \frac{1}{3}$

# %% [markdown]
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{24,000}{540,000}$$

# %%
expr_raw = r"\frac{24,000}{540,000}"
frac = sp.Rational(24_000, 540_000)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{24,000}{540,000} \,= \, \frac{2}{45}$

# %% [markdown]
# ## Video 5
#
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{84}{56}$$

# %%
expr_raw = r"\frac{84}{56}"
frac = sp.Rational(84, 56)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{84}{56} \,= \, \frac{3}{2}$

# %% [markdown]
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{441}{1323}$$

# %%
expr_raw = r"\frac{441}{1323}"
frac = sp.Rational(441, 1323)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{441}{1323} \,= \, \frac{1}{3}$

# %% [markdown]
# ## Video 6
#
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{210}{2100}$$

# %%
expr_raw = r"\frac{210}{2100}"
frac = sp.Rational(210, 2100)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{210}{2100} \,= \, \frac{1}{10}$

# %% [markdown]
# ### Cómo simplificar fracciones fácilmente
#
# $$\frac{700}{1,050}$$

# %%
expr_raw = r"\frac{700}{1,050}"
frac = sp.Rational(700, 1_050)

display(Math(rf"{expr_raw} {spacing_equal} {sp.latex(frac)}"))
# Out:
# $\displaystyle \frac{700}{1,050} \,= \, \frac{2}{3}$
