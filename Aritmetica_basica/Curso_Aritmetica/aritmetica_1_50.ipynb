# %% [markdown]
# # MateFacil

# %% [markdown]
# <img src="../../pics/cover.png" width=600>
#
# https://www.youtube.com/@MateFacilYT

# %% [markdown]
# ## Curso Completo de Aritmética
#
# <img src="../../pics/cover_curso_aritmetica.png" width=400>
#
# https://www.youtube.com/playlist?list=PL9SnRnlzoyX1MVuXSqPt2Q_gxC8RGcIu_

# %%
from astropy import units as u
import sympy as sp
from IPython.display import display, Math

a, m, x, y, z = sp.symbols("a, m, x, y, z", real=True)

# %% [markdown]
# ## Video 1
#
# Sumar:
#
# $$3081 + 56 + 310$$

# %%
expr_raw = r"3081 + 56 + 310"
expr_sp = 3081 + 56 + 310
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 3081 + 56 + 310 \,= \, 3447 $

# %% [markdown]
# ## Video 2
#
# Sumar:
#
# $$12187 + 1722 + 301 + 45$$

# %%
expr_raw = r"12187 + 1722 + 301 + 45"
expr_sp = 12187 + 1722 + 301 + 45
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 12187 + 1722 + 301 + 45 \,= \, 14255 $

# %% [markdown]
# ## Video 3
# Sumar:
#
# $$4310 + 216 + 1062 +6 + 55$$

# %%
expr_raw = r"4310 + 216 + 1062 + 6 + 55"
expr_sp = 4310 + 216 + 1062 + 6 + 55
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 4310 + 216 + 1062 + 6 + 55 \,= \, 5649 $

# %% [markdown]
# ## Video 4
#
# Sumar:
#
# $$162.4 + 20.31 + 1.025$$

# %%
expr_raw = r"162.4 + 20.31 + 1.025"
expr_sp = 162.4 + 20.31 + 1.025
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 162.4 + 20.31 + 1.025 \,= \, 183.735 $

# %% [markdown]
# ## Video 5
#
# Sumar:
#
# $$109.24 + 21.34 + 512 + 11.9$$

# %%
expr_raw = r"109.24 + 21.34 + 512 + 11.9"
expr_sp = 109.24 + 21.34 + 512 + 11.9
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 109.24 + 21.34 + 512 + 11.9 \,= \, 654.48 $

# %% [markdown]
# ## Video 6
#
# Sumar:
#
# $$0.152 + 1.31 + 21.05 +1.002 + 3.54$$

# %%
expr_raw = r"0.152 + 1.31 + 21.05 +1.002 + 3.54"
expr_sp = 0.152 + 1.31 + 21.05 + 1.002 + 3.54
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 0.152 + 1.31 + 21.05 +1.002 + 3.54 \,= \, 27.054 $

# %% [markdown]
# ## Video 7
#
# Sumar:
#
# ### 1)
#
# $$51 + 27$$

# %%
expr_raw = r"51 + 27"
expr_sp = 51 + 27
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 51 + 27 \,= \, 78 $

# %% [markdown]
# ### 2)
#
# $$435 + 67$$

# %%
expr_raw = r"435 + 67"
expr_sp = 435 + 67
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 435 + 67 \,= \, 502 $

# %% [markdown]
# ### 3)
#
# $$542 + 1287 + 79$$

# %%
expr_raw = r"542 + 1287 + 79"
expr_sp = 542 + 1287 + 79
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 542 + 1287 + 79 \,= \, 1908 $

# %% [markdown]
# ## Video 9
#
# Restar:
#
# $$9282 - 3521$$

# %%
expr_raw = r"9282 - 3521"
expr_sp = 9282 - 3521
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 9282 - 3521 \,= \, 5761 $

# %% [markdown]
# ## Video 10
#
# Restar:
#
# $$12504 - 9377$$

# %%
expr_raw = r"12504 - 9377"
expr_sp = 12504 - 9377
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 12504 - 9377 \,= \, 3127 $

# %% [markdown]
# ## Video 17
#
# Multiplicar:
#
# $$5216 \times 4$$

# %%
expr_raw = r"5216 \times 4"
expr_sp = 5216 * 4
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 5216 \times 4 \,= \, 20864 $

# %% [markdown]
# ## Video 18
#
# Multiplicar:
#
# $$16349 \times 8$$

# %%
expr_raw = r"16349 \times 8"
expr_sp = 16349 * 8
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 16349 \times 8 \,= \, 130792 $

# %% [markdown]
# ## Video 19
#
# Multiplicar:
#
# $$5216 \times 4$$

# %%
expr_raw = r"5216 \times 4"
expr_sp = 5216 * 4
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 5216 \times 4 \,= \, 20864 $

# %% [markdown]
# ## Video 20
#
# Multiplicar:
#
# $$3477 \times 27$$

# %%
expr_raw = r"3477 \times 27"
expr_sp = 3477 * 27
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 3477 \times 27 \,= \, 93879 $

# %% [markdown]
# ## Video 21
#
# Multiplicar:
#
# $$73914 \times 83$$

# %%
expr_raw = r"$73914 \times 83"
expr_sp = 73914 * 83
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 73914 \times 83 \,= \, 6134862 $

# %% [markdown]
# ## Video 22
#
# Multiplicar:
#
# $$26715 \times 317$$

# %%
expr_raw = r"26715 \times 317"
expr_sp = 26715 * 317
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 26715 \times 317 \,= \, 8468655 $

# %% [markdown]
# ## Video 27
#
# Multiplicar numeros con punto decimal
#
# $$41.72 \times 3.9$$

# %%
expr_raw = r"41.72 \times 3.9"
expr_sp = 41.72 * 3.9
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 41.72 \times 3.9 \,= \, 162.708 $

# %% [markdown]
# ## Video 28
#
# Multiplicar numeros con punto decimal
#
# $$4.429 \times 0.56$$

# %%
expr_raw = r"4.429 \times 0.56"
expr_sp = 4.429 * 0.56
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 4.429 \times 0.56 \,= \, 2.48024 $

# %% [markdown]
# ## Video 29
#
# Multiplicar numeros con punto decimal
#
# $$34.194 \times 2.51$$

# %%
expr_raw = r"34.194 \times 2.51"
expr_sp = 34.194 * 2.51
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 34.194 \times 2.51 \,= \, 85.82694 $

# %% [markdown]
# ## Video 39
#
# Multiplicar numeros con punto decimal
#
# $$3.2785 \times 2.641$$

# %%
expr_raw = r"3.2785 \times 2.641"
expr_sp = 3.2785 * 2.641
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 3.2785 \times 2.641 \,= \, 8.6585185 $

# %% [markdown]
# ## Video 32
#
# División y comprobación
#
# $$3396 \div 4$$

# %%
expr_raw = r"3396 \div 4"
expr_sp = 3396 / 4
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"

display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp)} "))
# Out:
# $\displaystyle 3396 \div 4 \,= \, 849.0 $

# %% [markdown]
# ## Video 33
#
# Dividir numeros
#
# $$78653 \div 7$$

# %%
expr_raw = r"78653 \div 7"
expr_sp = 78653 / 7
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.2f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 78653 \div 7 \,= \, \mathtt{\text{11236.14}} $

# %% [markdown]
# ## Video 34
#
# Dividir numeros
#
# $$94277 \div 8$$

# %%
expr_raw = r"94277 \div 8"
expr_sp = 94277 / 8
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.3f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 94277 \div 8 \,= \, \mathtt{\text{11784.625}} $

# %% [markdown]
# ## Video 35
#
# Dividir numeros
#
# $$35872 \div 13$$

# %%
expr_raw = r"35872 \div 13"
expr_sp = 35872 / 13
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.3f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 35872 \div 13 \,= \, \mathtt{\text{2759.385}} $

# %% [markdown]
# ## Video 38
#
# Dividir numeros
#
# $$207936 \div 83$$

# %%
expr_raw = r"207936 \div 83"
expr_sp = 207936 / 83
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.3f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 207936 \div 83 \,= \, \mathtt{\text{2505.253}} $

# %% [markdown]
# ## Video 40
#
# Dividir numeros
#
# $$297518 \div 285$$

# %%
expr_raw = r"297518 \div 285"
expr_sp = 297518 / 285
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.3f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 297518 \div 285 \,= \, \mathtt{\text{1043.923}} $

# %% [markdown]
# ## Video 42
#
# Dividir numeros
#
# $$24380118 \div 3902$$

# %%
expr_raw = r"24380118 \div 3902"
expr_sp = 24380118 / 3902
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.3f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 24380118 \div 3902 \,= \, \mathtt{\text{6248.108}} $

# %% [markdown]
# ## Video 43
#
# Dividir numeros
#
# $$57.29 \div 6$$

# %%
expr_raw = r"57.29 \div 6"
expr_sp = 57.29 / 6
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.4f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 57.29 \div 6 \,= \, \mathtt{\text{9.5483}} $

# %% [markdown]
# ## Video 44
#
# Dividir numeros
#
# $$2.9663 \div 7$$

# %%
expr_raw = r"2.9663 \div 7"
expr_sp = 2.9663 / 7
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.5f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 2.9663 \div 7 \,= \, \mathtt{\text{0.42376}} $

# %% [markdown]
# ## Video 45
#
# Dividir numeros
#
# $$379.562 \div 0.8$$

# %%
expr_raw = r"379.562 \div 0.8"
expr_sp = 379.562 / 0.8
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.4f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 379.562 \div 0.8 \,= \, \mathtt{\text{474.4525}} $

# %% [markdown]
# ## Video 46
#
# Dividir numeros
#
# $$89.1772 \div 2.1$$

# %%
expr_raw = r"89.1772 \div 2.1"
expr_sp = 89.1772 / 2.1
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.4f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 89.1772 \div 2.1 \,= \, \mathtt{\text{42.4653}} $

# %% [markdown]
# ## Video 50
#
# Dividir numeros
#
# $$3419.3 \div 1.05$$

# %%
expr_raw = r"3419.3 \div 1.05"
expr_sp = 3419.3 / 1.05
# spacing = r"\quad = \qquad"  # Ajusta la cantidad de \qquad según necesites
spacing = r"\,= \,"
expr_sp_format = f"{expr_sp:.4f}"
display(Math(rf"{expr_raw} {spacing} {sp.latex(expr_sp_format)} "))
# Out:
# $\displaystyle 3419.3 \div 1.05 \,= \, \mathtt{\text{3256.4762}} $

# %%
# Out:
# 9.0

# %%
# Out:
# 9.0

# %%
# Out:
# 9.0
